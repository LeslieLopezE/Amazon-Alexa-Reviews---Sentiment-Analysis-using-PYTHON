# %%
import logging
import pandas as pd
import numpy as np
from numpy import random
import seaborn as sns
import gensim
from gensim import corpora
from gensim.models import LdaModel, LdaMulticore
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup
# %matplotlib inline
from textblob import TextBlob 
from textblob.classifiers import NaiveBayesClassifier
import pickle
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc, log_loss
from nltk.sentiment import SentimentIntensityAnalyzer
from random import shuffle
from statistics import mean

# %%
data = pd.read_csv('amazon_alexa.csv')
data.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
data.shape
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3150 entries, 0 to 3149
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rating            3150 non-null   int64
#  1   date              3150 non-null   object
#  2   variation         3150 non-null   object
#  3   verified_reviews  3150 non-null   object
#  4   feedback          3150 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 123.2+ KB

# %%
dataset = data.drop('date', axis = 1)
dataset.head()
# Out:
#    rating         variation  \
# 0       5  Charcoal Fabric
# 1       5  Charcoal Fabric
# 2       4    Walnut Finish
# 3       5  Charcoal Fabric
# 4       5  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %% [markdown]
# ### FINDING SENTIMENT AND ADDING IT TO THE DATASET

# %%
dataset['feedback'] = np.where(dataset['feedback'].isin([1]), 'pos', 'neg')
dataset.head(3)
# Out:
#    rating         variation  \
# 0       5  Charcoal Fabric
# 1       5  Charcoal Fabric
# 2       4    Walnut Finish
#
#                                     verified_reviews feedback
# 0                                          love echo      neg
# 1                                              loved      neg
# 2  sometimes playing game answer question correct...      neg

# %%
dataset['verified_reviews'].apply(lambda x: len(x.split(' '))).sum()
# Out:
# 40695

# %% [markdown]
# There are 40695 words in the verified_reviews data

# %% [markdown]
# ### TEXT PRE-PROCESSING

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
STOPWORDS.update(["everyone", "sometimes", "Echo", "verified_reviews", "dtype", "object", "Alexa", "thing", "dot", "now", "one", "item", "bought", "will", "still", "without"])


def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    #text = BeautifulSoup(text, "lxml").text # HTML decoding
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text
    text = BAD_SYMBOLS_RE.sub('', text) # delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # delete stopwors from text
    return text
    
dataset['verified_reviews'] = dataset['verified_reviews'].apply(clean_text)
print (dataset['verified_reviews'])
# Out:
# 0                                               love echo
# 1                                                   loved
# 2       playing game answer question correctly alexa s...
# 3       lot fun 4 yr old learns dinosaurs control ligh...
# 4                                                   music
#                               ...
# 3145                                  perfect kids adults
# 3146    listening music searching locations checking t...
# 3147    love things running entire home tv lights ther...
# 3148    complaint sound quality isnt great mostly use ...
# 3149                                                 good
# Name: verified_reviews, Length: 3150, dtype: object

# %%
dataset['verified_reviews'].apply(lambda x: len(x.split(' '))).sum()
# Out:
# 39361

# %% [markdown]
# After cleaning up the data we have 39361 words to work with

# %% [markdown]
# ### TRANSFORMING REVIEWS INTO A CORPUS (CREATE DICTIONARY) AND FINDING WORD FREQUENCY

# %%
# CREATE DICTIONARY TO COUNT THE WORDS
count_dict_alexareviews = {}
for doc in dataset['verified_reviews']:
    for word in doc.split():
        if word in count_dict_alexareviews.keys():
            count_dict_alexareviews[word] +=1
        else:
            count_dict_alexareviews[word] = 1
            
for key, value in sorted(count_dict_alexareviews.items(), key=lambda item: item[1]):
    print("%s: %s" % (key, value))
# Out:
# dinosaurs: 1
# categories: 1
# grandaughter: 1
# 2000: 1
# miles: 1
# duty: 1
# boost: 1
# definitively: 1
# input: 1
# select: 1
# encyclopedias: 1
# greatit: 1
# lightswithout: 1
# chair: 1
# refunds: 1
# pauses: 1
# pattern: 1
# promp: 1
# poop: 1
# joke#34: 1
# naw: 1
# dollar: 1
# outsmart: 1
# youll: 1
# foot: 1
# performing: 1
# 6th: 1
# divertido: 1
# 1000: 1
# speaknspell: 1
# iove: 1
# attach: 1
# soundgood: 1
# fm: 1
# native: 1
# americans: 1
# whose: 1
# texas: 1
# birth: 1
# additionally: 1
# marginal: 1
# extender: 1
# ten: 1
# dust: 1
# collectors: 1
# fixes#34: 1
# accomplished: 1
# acknowledge: 1
# indicated: 1
# perfectlyvery: 1
# productsand: 1
# journey: 1
# daytoday: 1
# surely: 1
# portion: 1
# leary: 1
# puny: 1
# wear: 1
# tear: 1
# shuts: 1
# mint: 1
# teenagers: 1
# insist: 1
# lifechanging: 1
# young: 1
# simplicity: 1
# gazebo: 1
# sortof: 1
# complaini: 1
# timeworks: 1
# diagnostics: 1
# corrected: 1
# roomba: 1
# reboot: 1
# sentence: 1
# holding: 1
# action: 1
# onehonestly: 1
# productonce: 1
# itthis: 1
# shocked: 1
# clone: 1
# boat: 1
# garage: 1
# gf: 1
# intermittently: 1
# channel: 1
# pulsate: 1
# pulsed: 1
# buddies: 1
# easierthough: 1
# psychological: 1
# excellently: 1
# whe: 1
# 3dots: 1
# 2original: 1
# reconditioned: 1
# pare: 1
# weary: 1
# actively: 1
# 34: 1
# release: 1
# widespread: 1
# prevent: 1
# cortna: 1
# alive: 1
# thumbs: 1
# workreat: 1
# registered: 1
# spanking: 1
# laying: 1
# moana: 1
# sht: 1
# wherever: 1
# cordthank: 1
# verygod: 1
# fanlove: 1
# brandunlimited: 1
# musicprime: 1
# videoseven: 1
# output: 1
# vintage: 1
# longevity: 1
# compliments: 1
# bough: 1
# bathrooms: 1
# mothershe: 1
# responsivecan: 1
# detect: 1
# 1220: 1
# significant: 1
# shelled: 1
# electronically: 1
# savy: 1
# sink: 1
# refurbishedthought: 1
# eye: 1
# drops: 1
# closed: 1
# backyard: 1
# assumed: 1
# standards: 1
# guaranteeing: 1
# junkthey: 1
# sometime: 1
# haywire: 1
# soft: 1
# advised: 1
# 2999: 1
# raised: 1
# dealset: 1
# iphones: 1
# dunno: 1
# rambled: 1
# unhelpful: 1
# spielim: 1
# norm: 1
# busy: 8
# line: 8
# example: 8
# 6: 8
# four: 8
# wall: 8
# schedule: 8
# repeat: 8
# equipment: 8
# minor: 8
# sleeping: 8
# unplugged: 8
# condition: 8
# slightly: 8
# hears: 8
# tap: 8
# forget: 8
# source: 8
# inside: 8
# returned: 8
# looked: 8
# alexa#34: 8
# button: 8
# message: 8
# become: 8
# close: 8
# decent: 8
# doorbell: 8
# shut: 8
# saw: 8
# based: 8
# type: 8
# surprisingly: 8
# calendar: 8
# complaint: 8
# short: 8
# currently: 8
# cards: 8
# directions: 8
# unable: 8
# light#34: 8
# roku: 8
# laugh: 9
# specific: 9
# follow: 9
# review: 9
# ended: 9
# sister: 9
# expect: 9
# considering: 9
# primarily: 9
# function: 9
# lighting: 9
# believe: 9
# contact: 9
# entire: 9
# 7: 9
# happier: 9
# turning: 9
# recognize: 9
# particular: 9
# design: 9
# various: 9
# helped: 9
# returning: 9
# otherwise: 9
# maybe: 9
# speaking: 9
# fairly: 9
# missing: 9
# upgrade: 9
# compact: 9
# waste: 9
# arent: 9
# word: 9
# trek: 9
# research: 9
# outstanding: 9
# sonos: 9
# microphone: 9
# customer: 9
# guy: 9
# knows: 9
# lower: 9
# expensive: 9
# ai: 9
# gone: 9
# version: 9
# together: 9
# linked: 9
# hands: 9
# searching: 9
# 30: 9
# basically: 9
# receive: 9
# stay: 9
# network: 9
# please: 9
# notifications: 9
# delivered: 9
# create: 9
# lock: 9
# blast: 9
# correctly: 10
# improvement: 10
# color: 10
# choices: 10
# understands: 10
# podcasts: 10
# continue: 10
# operate: 10
# units: 10
# digital: 10
# lets: 10
# discovered: 10
# grandkids: 10
# stops: 10
# open: 10
# grocery: 10
# finding: 10
# language: 10
# large: 10
# intuitive: 10
# either: 10
# info: 10
# installation: 10
# kasa: 10
# due: 10
# gotten: 10
# amazed: 10
# potential: 10
# arrived: 10
# ago: 10
# bathroom: 10
# calling: 10
# stream: 10
# software: 10
# improve: 10
# larger: 10
# run: 10
# 20: 10
# pick: 10
# stereo: 10
# middle: 10
# black: 10
# realize: 10
# reviews: 10
# slow: 10
# cost: 10
# world: 10
# front: 10
# point: 10
# selection: 10
# space: 10
# hulu: 10
# dad: 11
# knew: 11
# expecting: 11
# allow: 11
# compatible: 11
# savvy: 11
# hearing: 11
# gadget: 11
# lives: 11
# outside: 11
# ways: 11
# upgraded: 11
# simply: 11
# kindle: 11
# search: 11
# beginning: 11
# replaced: 11
# requests: 11
# telling: 11
# automation: 11
# let: 11
# intercom: 11
# unfortunately: 11
# enjoyed: 11
# step: 11
# fan: 11
# recognition: 11
# cooking: 11
# replacement: 11
# adapter: 11
# save: 11
# theres: 11
# tool: 11
# completely: 11
# interface: 11
# seeing: 11
# try#34: 11
# takes: 11
# anyone: 11
# oh: 11
# idea: 11
# u: 12
# sent: 12
# saying: 12
# birthday: 12
# sync: 12
# purchasing: 12
# cheap: 12
# running: 12
# siri: 12
# others: 12
# alexia: 12
# thinking: 12
# traffic: 12
# within: 12
# fault: 12
# clearly: 12
# recommend: 48
# old: 49
# something: 49
# hear: 49
# cool: 49
# wanted: 49
# gift: 50
# fine: 50
# google: 52
# wifi: 52
# thought: 52
# ive: 53
# havent: 54
# size: 54
# though: 54
# etc: 55
# go: 55
# listening: 55
# connected: 55
# stick: 55
# times: 56
# expected: 56
# bluetooth: 57
# news: 57
# find: 57
# watch: 57
# volume: 59
# sure: 59
# fire: 59
# kitchen: 60
# 2: 60
# dots: 60
# happy: 61
# small: 61
# pretty: 62
# every: 63
# refurbished: 64
# make: 65
# going: 65
# features: 66
# questions: 66
# tell: 66
# speakers: 67
# family: 67
# working: 68
# didnt: 68
# playing: 69
# say: 69
# connect: 71
# two: 72
# way: 72
# perfect: 74
# control: 75
# awesome: 75
# first: 75
# wish: 76
# light: 76
# lot: 77
# purchased: 77
# best: 77
# app: 77
# bedroom: 80
# listen: 80
# another: 82
# sounds: 82
# amazing: 82
# think: 83
# purchase: 83
# getting: 84
# setup: 84
# phone: 84
# many: 85
# price: 89
# see: 90
# turn: 94
# lights: 94
# used: 94
# know: 94
# video: 94
# nice: 96
# cant: 96
# hub: 96
# spot: 97
# voice: 98
# using: 99
# clock: 99
# want: 100
# could: 100
# weather: 104
# buy: 105
# able: 107
# need: 108
# little: 109
# alarm: 110
# ask: 111
# learning: 112
# doesnt: 112
# #34: 113
# house: 115
# screen: 115
# everything: 119
# tv: 123
# plus: 124
# room: 126
# devices: 131
# got: 133
# even: 134
# far: 144
# things: 145
# show: 148
# fun: 151
# day: 153
# work: 154
# dont: 154
# well: 163
# quality: 166
# also: 168
# prime: 169
# much: 172
# new: 173
# better: 175
# smart: 181
# really: 193
# time: 195
# device: 212
# home: 215
# play: 215
# would: 217
# im: 232
# speaker: 238
# get: 243
# product: 249
# amazon: 253
# good: 273
# set: 296
# sound: 334
# easy: 339
# works: 378
# use: 466
# like: 501
# music: 531
# alexa: 608
# great: 719
# echo: 830
# love: 951

# %%
# REMOVE WORDS THAT OCCUR LESS THAN 10 TIMES
low_value = 10
bad_words = [key for key in count_dict_alexareviews.keys() if count_dict_alexareviews[key] < low_value]

# CREATE A LIST OF LISTS - EACH DOCUMENT IS A STRING BROKEN INTO A LIST OF WORDS
corpus = [doc.split() for doc in dataset['verified_reviews']]
clean_list = []
for document in corpus:
    clean_list.append([word for word in document if word not in bad_words])
clean_list
# Out:
# [['love', 'echo'],
#  ['loved'],
#  ['playing',
#   'answer',
#   'question',
#   'correctly',
#   'alexa',
#   'says',
#   'got',
#   'wrong',
#   'answers',
#   'like',
#   'able',
#   'turn',
#   'lights',
#   'away',
#   'home'],
#  ['lot',
#   'fun',
#   '4',
#   'old',
#   'control',
#   'lights',
#   'play',
#   'games',
#   'like',
#   'nice',
#   'sound',
#   'playing',
#   'music',
#   'well'],
#  ['music'],
#  ['received',
#   'echo',
#   'gift',
#   'needed',
#   'another',
#   'bluetooth',
#   'something',
#   'play',
#   'music',
#   'easily',
#   'found',
#   'smart',
#   'speaker',
#   'cant',
#   'wait',
#   'see',
#   'else'],
#  ['cannot',
#   'use',
#   'many',
#   'features',
#   'see',
#   'use',
#   'great',
#   'alarm',
#   'u',
#   'almost',
#   'hear',
#   'alarm',
#   'bedroom',
#   'living',
#   'room',
#   'reason',
#   'enough',
#   'keep',
#   'fun',
#   'ask',
#   'questions',
#   'hear',
#   'response',
#   'seem',
#   'yet'],
#  ['think',
#   'ive',
#   'purchased',
#   'im',
#   'working',
#   'getting',
#   'every',
#   'room',
#   'house',
#   'really',
#   'like',
#   'features',
#   'playing',
#   'music',
#   'echos',
#   'lights',
#   'throughout',
#   'house'],
#  ['looks', 'great'],
#  ['love',
#   'ive',
#   'songs',
#   'havent',
#   'heard',
#   'since',
#   'get',
#   'news',
#   'weather',
#   'information',
#   'great'],
#  ['sent', 'year', 'old', 'dad', 'constantly'],
#  ['love',
#   'learning',
#   'knew',
#   'things',
#   'everything',
#   'works',
#   'far',
#   'easy',
#   'use',
#   'understand',
#   'make',
#   'times'],
#  ['purchased',
#   'mother',
#   'problems',
#   'give',
#   'something',
#   'trying',
#   'come',
#   'getting',
#   'around',
#   'fast',
#   'like',
#   'little',
#   'big',
#   'things',
#   'play',
#   'song',
#   'time'],
#  ['love', 'love', 'love'],
#  ['expected'],
#  ['love', 'wife'],
#  ['really', 'happy', 'purchase', 'great', 'speaker', 'easy', 'set'],
#  ['using',
#   'alexa',
#   'couple',
#   'days',
#   'lot',
#   'fun',
#   'new',
#   'toy',
#   'like',
#   'new',
#   'household',
#   'trying',
#   'learn',
#   'different',
#   'come'],
#  ['love',
#   'size',
#   '2nd',
#   'generation',
#   'echo',
#   'needs',
#   'little',
#   'improvement',
#   'sound'],
#  ['liked',
#   'original',
#   'echo',
#   'color',
#   'choices',
#   'miss',
#   'volume',
#   'ring',
#   'top',
#   'plus',
#   'buttons',
#   'big',
#   'deal',
#   'ring',
#   'well',
#   'like',
#   'use',
#   'instead',
#   'sounds',
#   'seems',
#   'work',
#   'answers',
#   'alexa',
#   'echo',
#   'computer',
#   'whats',
#   'like'],
#  ['love',
#   'echo',
#   'good',
#   'music',
#   'sounds',
#   'playing',
#   'alexa',
#   'understands',
#   'commands',
#   'difficult',
#   'times',
#   'find',
#   'songs',
#   'spotify',
#   'good',
#   'amazon',
#   'music',
#   'programs'],
#  ['love',
#   'alexa',
#   'use',
#   'play',
#   'music',
#   'play',
#   'radio',
#   'play',
#   'podcasts',
#   'set',
#   'reminders',
#   'listen',
#   'flash',
#   'briefing',
#   'news',
#   'weather',
#   'every',
#   'morning',
#   'lists',
#   'like',
#   'able',
#   'voice',
#   'control',
#   'volume',
#   'sure',
#   'well',
#   'continue',
#   'find',
#   'new',
#   'bit',
#   'frustrating',
#   'alexa',
#   'doesnt',
#   'understand',
#   'saying'],
#  ['set',
#   'days',
#   'adding',
#   'smart',
#   'home',
#   'devices',
#   'speaker',
#   'great',
#   'playing',
#   'music',
#   'like',
#   'size',
#   'kitchen',
#   'look'],
#  ['love', 'plays', 'sleep', 'sounds', 'immediately', 'ask'],
#  ['got',
#   'second',
#   'unit',
#   'bedroom',
#   'expecting',
#   'sounds',
#   'didnt',
#   'really',
#   'see',
#   'difference',
#   'overall',
#   'big',
#   'improvement',
#   '1st',
#   'generation'],
#  ['amazing', 'product'],
#  ['love',
#   'echo',
#   'easy',
#   'operate',
#   'everything',
#   'advertised',
#   'use',
#   'mainly',
#   'play',
#   'favorite'],
#  ['sounds', 'great', 'love'],
#  ['fun',
#   'play',
#   'get',
#   'used',
#   'using',
#   'hard',
#   'time',
#   'questions',
#   'ask',
#   'think',
#   'better'],
#  ['like'],
#  ['learning', 'far', 'pretty', 'pretty', 'pretty', 'good'],
#  ['like'],
#  ['works',
#   'well',
#   'needs',
#   'learning',
#   'command',
#   'like',
#   'alexa',
#   'learn',
#   'birthday',
#   'alexa',
#   'learn',
#   'fine',
#   'etc',
#   'great'],
#  ['speakers',
#   'sound',
#   'pretty',
#   'good',
#   'small',
#   'setup',
#   'pretty',
#   'easy',
#   'two',
#   'reason',
#   '3',
#   'instructions',
#   'music',
#   'units',
#   'know',
#   'ive',
#   'done',
#   'correctly',
#   'wont',
#   'sync',
#   'purchasing',
#   'multiple',
#   'units'],
#  ['device', 'awesome'],
#  ['speaker',
#   'quality',
#   'first',
#   'generation',
#   'speaker',
#   'like',
#   'sound',
#   'better',
#   'daughter',
#   'though',
#   'like',
#   'fact',
#   'first',
#   'generation',
#   'base',
#   'keeps',
#   'needs',
#   'better',
#   'sound'],
#  ['love',
#   'echo',
#   'learning',
#   'things',
#   'wasnt',
#   'able',
#   'instructions',
#   'included',
#   'package',
#   'found',
#   'great'],
#  ['speaker', 'better', '1st', 'generation', 'echo'],
#  ['way', 'cool', 'get', 'want', 'cool'],
#  ['first',
#   'digital',
#   'assistant',
#   'im',
#   'good',
#   'speaker',
#   'really',
#   'good',
#   'cheap',
#   'price',
#   'prime',
#   'day',
#   'fun',
#   'play',
#   'used',
#   'alarm',
#   'clock',
#   'thats',
#   'going',
#   'get',
#   'first',
#   'echo',
#   'havent',
#   'go',
#   'definitely',
#   'try',
#   'like',
#   'best',
#   'number',
#   'devices',
#   'connect',
#   'purchase',
#   'came',
#   'smart',
#   'plug',
#   '10',
#   'connect',
#   'lamp',
#   'alexa',
#   'turn',
#   'lights'],
#  ['husband', 'able', 'use', 'listen', 'music', 'wish', 'knew', 'capabilities'],
#  ['would',
#   'allow',
#   'alexa',
#   'connect',
#   'apple',
#   'cell',
#   'tech',
#   'support',
#   'running'],
#  ['far', 'good'],
#  ['tried', 'play', 'shows', 'like', 'gives', 'group'],
#  ['great'],
#  ['satisfied',
#   'echo',
#   'alexa',
#   'lights',
#   'family',
#   'room',
#   'wife',
#   'listen',
#   'asking',
#   'alexa'],
#  ['like',
#   'siri',
#   'fact',
#   'siri',
#   'answers',
#   'alexa',
#   'dont',
#   'see',
#   'real',
#   'need',
#   'household',
#   'though',
#   'good',
#   'prime',
#   'day'],
#  ['love', 'echo', 'learning', 'every', 'works', 'fun'],
#  ['love', 'much'],
#  ['different',
#   'apple',
#   'play',
#   'list',
#   'music',
#   'must',
#   'amazon',
#   'spotify',
#   'plus',
#   'prime',
#   'etc',
#   'account',
#   'must',
#   'pay',
#   'play',
#   'music',
#   '3',
#   'stars',
#   'reason',
#   'everything',
#   'else'],
#  [],
#  ['im',
#   'learning',
#   'use',
#   'far',
#   'echo',
#   'great',
#   'sound',
#   'actually',
#   'much',
#   'better',
#   'expecting'],
#  ['works', 'also', 'good', 'sound', 'quality', 'price', 'sale', 'features'],
#  ['sound', 'echo', '2nd', 'generation', 'love', 'alexa', 'helpful'],
#  ['like', 'google', 'better'],
#  ['lets', 'play', 'learn', 'get'],
#  ['works', 'advertised', 'easy', 'setup', 'learning'],
#  ['great', 'sound', 'easy', 'set'],
#  ['love', 'alexa', 'others', 'friends'],
#  ['love',
#   'echo',
#   'purchased',
#   'husband',
#   'alexa',
#   'great',
#   'say',
#   'name',
#   'tells',
#   'plays',
#   'favorite',
#   'songs'],
#  [],
#  ['love',
#   'able',
#   'listen',
#   'music',
#   'easily',
#   'learning',
#   'features',
#   'available'],
#  ['really', 'know', 'could', 'use', 'device', 'used', 'things', 'need'],
#  ['love', 'wish', 'built', 'hub'],
#  ['use',
#   'play',
#   'music',
#   'works',
#   'getting',
#   'used',
#   'many',
#   'things',
#   'amazon',
#   'sent',
#   'several',
#   'since',
#   'got',
#   'thanks',
#   'help'],
#  ['easy', 'set'],
#  ['fast',
#   'response',
#   'amazing',
#   'clear',
#   'answers',
#   'sound',
#   'quality',
#   'fantastic',
#   'getting',
#   'used',
#   'alexia',
#   'echo',
#   'full'],
#  ['youre'],
#  ['everything', 'expected'],
#  ['love',
#   'echo',
#   'works',
#   'like',
#   'said',
#   'would',
#   'dont',
#   '#34',
#   'home',
#   'cannot',
#   'speak',
#   'everything',
#   'else',
#   'good'],
#  ['great', 'sound', 'small', 'set', 'use', 'fun'],
#  ['works', 'sounds', 'great'],
#  ['sound', 'amazing', 'many', 'music'],
#  ['setting'],
#  ['doesnt', 'always', 'listen'],
#  ['awesome'],
#  ['control',
#   'works',
#   'well',
#   'im',
#   'hoping',
#   'time',
#   'control',
#   'discovered',
#   'things',
#   'alexa',
#   'play',
#   'music',
#   'ask',
#   'great',
#   'sound',
#   'alexa',
#   'play',
#   'games',
#   'play',
#   'radio',
#   'stations',
#   'play',
#   'old',
#   'time',
#   'radio',
#   'programs',
#   'like',
#   'long',
#   'alexa',
#   'many',
#   'apps',
#   'add',
#   'day',
#   'played',
#   'great',
#   'fun',
#   'also',
#   'alexa',
#   'control',
#   'household',
#   'purchased',
#   'alexa',
#   'compatible',
#   'power',
#   'control',
#   'tv',
#   'im',
#   'looking',
#   'forward',
#   'also',
#   'add',
#   'alexa',
#   'music',
#   'play',
#   'rooms'],
#  ['speaker', 'excellent', 'sound', 'works', 'perfectly'],
#  ['like'],
#  ['love', 'everything'],
#  ['little',
#   'received',
#   'new',
#   'echo',
#   'im',
#   'really',
#   'tech',
#   'savvy',
#   'found',
#   'bit',
#   'first',
#   'didnt',
#   'take',
#   'long',
#   'figure',
#   'im',
#   'happy',
#   'purchase',
#   'thinking',
#   'adding',
#   'echo',
#   'spot'],
#  ['like', 'learning', 'use'],
#  ['great',
#   'technology',
#   'cant',
#   'speaker',
#   'volume',
#   'quality',
#   'wonderful',
#   'wish',
#   'another'],
#  ['purchased',
#   'echo',
#   'husband',
#   'day',
#   'uses',
#   'constantly',
#   'hearing',
#   'quality',
#   'sound',
#   'echo',
#   '2nd',
#   'generation',
#   'best',
#   'gift',
#   'ever'],
#  ['works', 'fine'],
#  [],
#  ['clear', 'music'],
#  ['fun', 'use', 'good', 'sound', 'quality'],
#  ['echo', 'works', 'well', 'able', 'sync', 'amazon', 'music', 'devices'],
#  ['works',
#   'great',
#   'dont',
#   'think',
#   'amazon',
#   'another',
#   'music',
#   '1',
#   'prime',
#   '2',
#   'buy',
#   'echo'],
#  ['already',
#   'echo',
#   'echo',
#   'even',
#   'better',
#   'sound',
#   'also',
#   'setup',
#   'lets',
#   'phone',
#   'calls',
#   'made',
#   'list',
#   'great'],
#  ['speaker', 'sounds', 'really', 'good'],
#  ['good', 'sound', 'works', 'well'],
#  ['love', 'alexa', 'savvy', 'support', 'helpful'],
#  ['love',
#   'thinking',
#   'getting',
#   'prime',
#   'day',
#   'could',
#   'fun',
#   'ask',
#   'alexa',
#   'play',
#   'song',
#   'group',
#   'comes',
#   'playlist',
#   'amazon',
#   'prime',
#   'music',
#   'also',
#   'connect',
#   'bluetooth',
#   'play',
#   'music',
#   'pandora',
#   'youtube',
#   'videos',
#   'using',
#   'alexa',
#   'speaker',
#   'ive',
#   'fun',
#   'asking',
#   'alexa',
#   'different',
#   'questions',
#   'information',
#   'like',
#   'weather',
#   'news',
#   'even',
#   'time',
#   'limited',
#   'wifi',
#   'plan',
#   'alexa',
#   'uses',
#   'playing',
#   'music'],
#  ['like', 'far', 'lot', 'try', 'yet'],
#  ['love', 'using', 'music', 'great'],
#  ['love',
#   'echo',
#   'love',
#   'size',
#   'speaker',
#   'quality',
#   'hooked',
#   'light',
#   'easily',
#   'work',
#   'additional',
#   'lights',
#   'thermostat',
#   'next',
#   'echo',
#   'bedroom',
#   'lot',
#   'echo',
#   'think',
#   'traffic',
#   'weather',
#   'etc'],
#  ['love'],
#  ['family', 'loves', 'alexa', 'echo', 'shes', 'part', 'family'],
#  ['great',
#   'fun',
#   'getting',
#   'know',
#   'functions',
#   'product',
#   'family',
#   'fun',
#   'help',
#   'talking',
#   'also',
#   'echo',
#   'huge',
#   'cant',
#   'wait',
#   'learn'],
#  ['love'],
#  ['awesome', 'love', 'alexa'],
#  ['worked', 'exactly', 'expected', 'speaker', 'great', 'sound', 'perfect'],
#  ['love',
#   'love',
#   'new',
#   'little',
#   'gadget',
#   'made',
#   'lives',
#   'much',
#   'easier',
#   'like',
#   'personal',
#   'living',
#   'home',
#   'need',
#   'since',
#   'alexa',
#   'plays',
#   'everything',
#   'need',
#   'going',
#   'get',
#   'alexa',
#   'dots',
#   'soon',
#   'rooms',
#   'thanks'],
#  ['speaker', 'quality', 'happy', 'purchase'],
#  ['easy', 'set', 'works', 'wonderful', 'love'],
#  ['im',
#   'really',
#   'impressed',
#   'sound',
#   'quality',
#   'playing',
#   'music',
#   'device',
#   'bass',
#   'sounds',
#   'almost',
#   'like',
#   'speaker',
#   'amazon'],
#  ['great',
#   'sound',
#   'quality',
#   'seem',
#   'get',
#   'wrong',
#   'definitely',
#   'get',
#   'used',
#   'within',
#   'definitely',
#   'like',
#   'echo',
#   'gen',
#   '1',
#   'sound',
#   'quality',
#   'addition',
#   'able',
#   'play',
#   'bluetooth',
#   'wifi',
#   'even',
#   'better'],
#  ['work', 'disappointed'],
#  ['great', 'device', 'responsive', 'helpful'],
#  ['sound', 'terrible', 'u', 'want', 'good', 'music', 'get', 'bose'],
#  ['liked',
#   'sound',
#   'paid',
#   'extra',
#   'money',
#   'access',
#   'songs',
#   'doesnt',
#   'work',
#   'alexa',
#   'play',
#   'dont',
#   'understand',
#   'play',
#   'response',
#   '#34'],
#  ['easy',
#   'set',
#   'use',
#   'bad',
#   'plugged',
#   'would',
#   'nice',
#   'take',
#   'outside',
#   'operate',
#   'battery'],
#  ['learning', 'ways', 'use', 'real', 'grandkids', 'ask', 'play', 'music', '5'],
#  ['5',
#   'stars',
#   'like',
#   'product',
#   'great',
#   'ask',
#   'like',
#   'playing',
#   'music',
#   'setting',
#   'timers',
#   'making',
#   'calls',
#   'reason',
#   'didnt',
#   '5',
#   '5',
#   'connection',
#   'echo',
#   'stops',
#   'playing',
#   'music',
#   'shows',
#   'ring',
#   'seems',
#   'connection',
#   'issue',
#   'overall',
#   'great',
#   'product'],
#  ['works', 'great', 'upgraded', 'echo', 'full', 'size', 'echo', 'couldnt'],
#  ['alexa', 'else', 'say'],
#  ['upgraded', 'echo', 'happy', 'sound'],
#  ['excellent', 'product', 'set', 'ease', 'well'],
#  ['ive',
#   'first',
#   'gen',
#   'echo',
#   'since',
#   'first',
#   'came',
#   'worked',
#   'well',
#   'purchased',
#   '2nd',
#   'gen',
#   'prime',
#   'day',
#   'far',
#   'im',
#   'happy',
#   'seems',
#   'speaker',
#   'sound',
#   'music'],
#  ['love',
#   'echo',
#   'smart',
#   'speaker',
#   'love',
#   'volume',
#   'easy',
#   'set',
#   'wonderful',
#   'gift'],
#  ['wonderful', 'product', 'fast'],
#  ['set', 'tech', 'wasnt', 'working', 'great'],
#  ['easy', 'set', 'family', 'love'],
#  ['great', 'sound', 'responsive', 'voice', 'commands'],
#  ['live',
#   'long',
#   'echo',
#   'get',
#   'enjoy',
#   'music',
#   'asking',
#   'alexa',
#   'going',
#   'wireless',
#   'love',
#   'echo',
#   'love',
#   'alexa'],
#  ['cool', 'product', 'speaker', 'sounds', 'good', 'spotify'],
#  ['much',
#   'fun',
#   'alexa',
#   'love',
#   'able',
#   'listen',
#   'music',
#   'im',
#   'across',
#   'room',
#   'something',
#   'else'],
#  ['far',
#   'seems',
#   'nice',
#   'voice',
#   'understands',
#   'problems',
#   'day',
#   'asked',
#   'turn',
#   'music',
#   'next',
#   'room',
#   'heard',
#   'fine',
#   'ive',
#   'used',
#   'listen',
#   'music',
#   'check',
#   'weather',
#   'done',
#   'things',
#   'well'],
#  ['love', 'echo'],
#  ['love',
#   'helpful',
#   'use',
#   'things',
#   'sleep',
#   'ask',
#   'anything',
#   'week',
#   'learning'],
#  ['better',
#   '1st',
#   'gen',
#   'every',
#   'way',
#   'except',
#   'really',
#   'miss',
#   'ring',
#   'top',
#   'volume',
#   'control',
#   'easier',
#   'top',
#   'look',
#   'buttons',
#   'find',
#   '#34',
#   '#34',
#   'times',
#   'also',
#   'wish',
#   'bass',
#   'bit',
#   'better',
#   'great',
#   'device',
#   'im',
#   'happy'],
#  ['love', 'alexa'],
#  ['far', 'like'],
#  ['enjoying',
#   'love',
#   'read',
#   'office',
#   'simply',
#   'open',
#   'kindle',
#   'continue',
#   'wonderful',
#   'listening',
#   'music',
#   'great',
#   'setting',
#   'reminders',
#   'much'],
#  ['love'],
#  ['love'],
#  ['love', 'sound', 'quality', 'unit', 'clear', 'sound'],
#  ['listening',
#   'talk',
#   'radio',
#   'morning',
#   'lights',
#   'etc',
#   'system',
#   'excellent',
#   'job',
#   'full',
#   'house',
#   'sound',
#   'system',
#   'streaming'],
#  ['week',
#   'learning',
#   'alexa',
#   'learning',
#   'process',
#   'love',
#   'music',
#   'call',
#   'time',
#   'listen',
#   'podcasts',
#   'radio',
#   'stations',
#   'started',
#   'shopping',
#   'lists',
#   'grocery',
#   'lists',
#   'love',
#   'dont',
#   'search',
#   'getting',
#   'time',
#   'great',
#   'wait',
#   'weather',
#   'sound',
#   'good',
#   'base',
#   'etc',
#   'echo',
#   'fine',
#   'going',
#   'try',
#   'son',
#   'gets',
#   'home',
#   'going'],
#  ['much', 'features'],
#  ['great',
#   'sound',
#   'quality',
#   'great',
#   'features',
#   'great',
#   'product',
#   'room',
#   'music',
#   'cool'],
#  ['cool'],
#  ['echo', 'two', 'three', 'echo'],
#  ['annoying',
#   'everything',
#   'show',
#   'alexa',
#   'able',
#   'much',
#   'time',
#   'trying',
#   'figure',
#   'may',
#   'well',
#   'look'],
#  ['alexa',
#   'since',
#   'beginning',
#   'replaced',
#   '2nd',
#   'generation',
#   'decided',
#   'couldnt',
#   'echo',
#   'setup',
#   'easy',
#   'working',
#   'within',
#   'minutes'],
#  ['like',
#   'able',
#   'tell',
#   'alexia',
#   'music',
#   'want',
#   'hear',
#   'trouble',
#   'finding',
#   'song'],
#  ['like',
#   'looks',
#   'better',
#   'original',
#   'echo',
#   'old',
#   'echo',
#   'family',
#   'room',
#   'nice',
#   'sound'],
#  ['echo',
#   'wonderful',
#   'im',
#   'learning',
#   'use',
#   'music',
#   'requests',
#   'limited'],
#  ['doesnt',
#   'know',
#   'half',
#   'things',
#   'asked',
#   'cant',
#   'wifi',
#   'even',
#   'though',
#   'product',
#   'says',
#   'compatible',
#   'cant',
#   'program',
#   'change',
#   'wifi',
#   'thermostat',
#   'settings',
#   'wifi',
#   'handy',
#   'music',
#   'thats',
#   'amazon',
#   'music'],
#  ['love'],
#  ['kids'],
#  ['surprised',
#   'sound',
#   'quality',
#   'many',
#   'features',
#   'nice',
#   'easily',
#   'hear',
#   'hear',
#   'books',
#   'simple',
#   'command',
#   'looking',
#   'forward',
#   'options',
#   'device'],
#  ['easy', 'set', 'really', 'quick'],
#  ['like',
#   'fact',
#   'get',
#   'kind',
#   'music',
#   'prime',
#   'want',
#   'request',
#   'alexa',
#   'liked',
#   'little',
#   'wish',
#   'included',
#   'connect',
#   'tv',
#   'etc',
#   'commands',
#   'alexa',
#   'really',
#   'love',
#   'music'],
#  ['found',
#   'way',
#   'access',
#   'echo',
#   'prime',
#   'account',
#   'think',
#   'part',
#   'top',
#   'video',
#   'music',
#   'etc',
#   'also',
#   'think',
#   'setup',
#   'app',
#   'music',
#   'like',
#   'well',
#   'echo',
#   'tried',
#   'ask',
#   'playlist',
#   'echo',
#   'sure',
#   'even',
#   'though',
#   'set',
#   'play',
#   'list',
#   'settings',
#   'also',
#   'like',
#   'fact',
#   'words',
#   'playlist',
#   'never',
#   'like',
#   'ready',
#   'echo',
#   'respond'],
#  ['great', 'added', 'audible', 'books', 'makes', 'even', 'better', 'thank'],
#  ['prime',
#   'day',
#   '2nd',
#   'gen',
#   'echo',
#   'sale',
#   'couldnt',
#   'beginning',
#   'smart',
#   'home',
#   'set',
#   'couldnt',
#   'say',
#   'alexa',
#   'done',
#   'amazing',
#   'job',
#   'connecting',
#   'smart',
#   'devices',
#   'thanks',
#   'control',
#   'lights',
#   'smart',
#   'plugs',
#   'tv',
#   'etc',
#   'trouble',
#   'connecting',
#   'echo',
#   'wifi',
#   'phone',
#   'app',
#   'works',
#   'perfectly',
#   'fine',
#   'lets',
#   'add',
#   'skills',
#   'smart',
#   'devices',
#   'timers',
#   'much',
#   'sound',
#   'quality',
#   'good',
#   'enough',
#   'since',
#   'alexa',
#   'hear',
#   'voice',
#   'even',
#   'watching',
#   'movies',
#   'high',
#   'volume',
#   'great',
#   'definitely',
#   'add',
#   'nice',
#   'touch',
#   'home',
#   'change',
#   'like',
#   'sale',
#   'overall',
#   'great',
#   'addition',
#   'home',
#   'many',
#   'havent',
#   'yet',
#   'sure',
#   'add',
#   'alexa',
#   'home'],
#  ['fun'],
#  ['works', 'great', 'speaker', 'wife', 'son', 'love'],
#  ['regret', 'long', 'purchase', 'surprised', 'pleased', 'sound', 'quality'],
#  ['stopped',
#   'working',
#   '2',
#   'weeks',
#   'didnt',
#   'commands',
#   'really',
#   'fun',
#   'working'],
#  ['far',
#   'love',
#   'working',
#   'getting',
#   'things',
#   'set',
#   'love',
#   'grocery',
#   'list',
#   'app'],
#  ['pretty',
#   'much',
#   'expected',
#   'disappointed',
#   'need',
#   'play',
#   'music',
#   'amazon',
#   'music',
#   'service',
#   'understand',
#   'music',
#   'choices',
#   'may',
#   'limited',
#   'ask',
#   'cannot',
#   'access',
#   'music',
#   'free',
#   'along',
#   'echo',
#   'purchase',
#   'language',
#   'need',
#   'use'],
#  ['easy', 'set'],
#  ['like', 'product', 'except', 'speakers', 'high', 'quality', 'expected'],
#  ['great', 'alexa', 'made'],
#  ['yet', 'another', 'home', 'love'],
#  ['love',
#   'plan',
#   'music',
#   'big',
#   'easy',
#   'find',
#   'radio',
#   'sound',
#   'good',
#   'stop',
#   'voice',
#   'command',
#   'get',
#   'phone',
#   'call'],
#  ['good', 'value'],
#  ['super', 'easy', 'set', 'loving', 'new', 'echo'],
#  ['whats', 'like', 'speaker', 'ask', 'alexa'],
#  ['best',
#   'day',
#   'gift',
#   'dad',
#   'mom',
#   'alexa',
#   'listening',
#   'going',
#   'forward'],
#  ['great',
#   'addition',
#   'room',
#   'kitchen',
#   'information',
#   'available',
#   'learning',
#   'features'],
#  ['sound', 'quality'],
#  [],
#  ['entertainment'],
#  ['good', 'quality'],
#  ['works', 'great', 'sounds', 'great', 'miss', 'wish', 'battery', 'better'],
#  ['loved', 'someone', 'cant', 'replace', 'yet', 'going'],
#  ['alexa'],
#  ['got',
#   'gift',
#   'love',
#   'never',
#   'would',
#   'play',
#   'music',
#   'prime',
#   'music',
#   'thats',
#   'worth',
#   'also',
#   'gives',
#   'news',
#   'tells',
#   'jokes'],
#  [],
#  ['mom',
#   'echo',
#   'dots',
#   'ask',
#   'take',
#   'great',
#   'told',
#   'two',
#   'days',
#   'made',
#   'take',
#   'hours',
#   'later',
#   'could',
#   'live',
#   'life',
#   'amazing',
#   'large',
#   'speakers',
#   'small',
#   'echo',
#   'say',
#   'youre',
#   'going',
#   'order',
#   'alexa',
#   'speaker',
#   'go',
#   'big',
#   'get',
#   'echo',
#   'two',
#   'echo',
#   'dots',
#   'couldnt',
#   'live'],
#  ['love', 'great', 'product'],
#  ['easy', 'set', 'user', 'friendly'],
#  ['really',
#   'disappointed',
#   'alexa',
#   'time',
#   'fault',
#   'checking',
#   'made',
#   'amazon',
#   'would',
#   'product',
#   'battery',
#   'could',
#   'return',
#   'would',
#   'apple',
#   'music',
#   'speaker',
#   'give',
#   'alexa'],
#  ['dont',
#   'think',
#   '#34',
#   '2nd',
#   'sounds',
#   'good',
#   '1st',
#   'could',
#   'add',
#   'external',
#   'speaker',
#   'going',
#   'wouldnt',
#   'get',
#   '2nd',
#   'issue',
#   'isnt',
#   'unit',
#   'dont',
#   'understand',
#   'cant',
#   'playing',
#   'blue',
#   'tooth',
#   'speaker',
#   'playing',
#   '#34',
#   'get',
#   'using',
#   'speaker',
#   'units',
#   'heard',
#   'able',
#   'play',
#   'group',
#   'using',
#   'speaker'],
#  ['everything'],
#  ['like',
#   'asking',
#   'questions',
#   'dont',
#   'like',
#   'cant',
#   'ask',
#   'setup',
#   'connected',
#   'lamp'],
#  ['sound', 'definitely', 'worth', 'extra', 'money', 'listen', 'lots', 'music'],
#  ['really',
#   'love',
#   'amazon',
#   'echo',
#   'think',
#   'sound',
#   'quality',
#   'great',
#   'lot',
#   'fun',
#   'really',
#   'handy',
#   'music',
#   'get',
#   'updates',
#   'weather'],
#  ['love', 'grandkids'],
#  ['far',
#   'worked',
#   'well',
#   'always',
#   'intuitive',
#   'link',
#   'different',
#   'devices',
#   'skills',
#   'getting'],
#  ['works', 'advertised'],
#  ['love'],
#  ['love',
#   'new',
#   'addition',
#   'house',
#   'speaker',
#   'quality',
#   'great',
#   'love',
#   'alexa',
#   'two',
#   'complaints',
#   'future',
#   'would',
#   'better',
#   'ability',
#   'smart',
#   'lights',
#   'house',
#   'unless',
#   'kitchen',
#   'light',
#   '1',
#   'kitchen',
#   'light',
#   '2',
#   'command',
#   'either',
#   'wont',
#   'respond',
#   'says',
#   'doesnt',
#   'may',
#   'want',
#   'alexa',
#   'respond',
#   'say',
#   'thank',
#   'alexa',
#   'thank',
#   'times',
#   'wont',
#   'respond',
#   'husband',
#   'know',
#   'sounds',
#   'want',
#   'alexa'],
#  ['like', 'everything', 'music', 'games', 'weather'],
#  ['received', 'time', 'like', 'music'],
#  ['great', 'device'],
#  ['echo',
#   'year',
#   'new',
#   'easy',
#   'way',
#   'volume',
#   'telling',
#   'volume',
#   'hard',
#   'wife',
#   'since',
#   'second',
#   'language',
#   'sound',
#   'echo',
#   'well',
#   'keep'],
#  ['love', 'kitchen', 'works', 'well'],
#  ['nice', 'im', 'impressed', 'wish', 'say', 'though'],
#  ['love', 'product', 'nice', 'easy', 'access', 'much', 'info'],
#  ['got', 'great', 'sound', 'bass', 'doesnt', 'work', 'time', 'miss', 'things'],
#  ['echo'],
#  ['amazing'],
#  ['good',
#   'hearing',
#   'range',
#   'sound',
#   'quality',
#   'bit',
#   'set',
#   'doesnt',
#   'quite',
#   'understand',
#   'lot',
#   'even',
#   'clearly',
#   'love',
#   'flash',
#   'briefing',
#   'feature',
#   'home',
#   'security',
#   'system'],
#  ['speaker', 'sounds', 'good'],
#  ['absolutely', 'love'],
#  ['best',
#   'part',
#   'product',
#   'control',
#   'thermostat',
#   'lights',
#   'house',
#   'isnt',
#   'anything',
#   'dislike'],
#  ['enjoying',
#   'amazon',
#   'echo',
#   'installation',
#   'easy',
#   'using',
#   'alexa',
#   'app',
#   'purchased',
#   '2',
#   'kasa',
#   'smart',
#   'plugs',
#   'control',
#   'living',
#   'room',
#   'lights',
#   'installation',
#   'easy',
#   'using',
#   'kasa',
#   'app',
#   'right',
#   'echo',
#   'enjoying',
#   'playing',
#   'music',
#   'echo',
#   'sound',
#   'quality',
#   'awesome',
#   'weve',
#   'added',
#   'kasa',
#   'smart',
#   'bulb',
#   'kitchen',
#   'setup',
#   'looking',
#   'forward',
#   'adding',
#   'automation',
#   'home'],
#  ['home', 'entertainment'],
#  ['cool',
#   'product',
#   'easy',
#   'setup',
#   'fun',
#   'use',
#   'sound',
#   'quality',
#   'much',
#   'better'],
#  ['love', 'great', 'sound', 'easy', 'connect', 'use'],
#  ['doesnt',
#   'work',
#   'new',
#   'smart',
#   'tv',
#   'thats',
#   'mainly',
#   'tv',
#   'fault',
#   'due',
#   'anything',
#   'older',
#   'year',
#   'smart',
#   'also',
#   'need',
#   'additional',
#   'piece',
#   'order',
#   'connect',
#   'well',
#   'speakers',
#   'sound',
#   'great',
#   'works',
#   'well'],
#  ['great', 'sound', 'little', 'speaker'],
#  ['enjoy'],
#  [],
#  ['cool'],
#  ['good', 'quality', 'great', 'sound', 'quality'],
#  ['works', 'perfectly'],
#  ['great',
#   'product',
#   'alexa',
#   'understand',
#   'commands',
#   'fire',
#   'tv',
#   'speaker'],
#  ['love', 'echo', 'great', 'sound', 'smart'],
#  ['sure', 'love'],
#  ['plays', 'great'],
#  ['works', 'absolutely', 'great'],
#  ['amazing', 'product', 'great', 'sound', 'quality'],
#  ['best', 'ive', 'thank', 'much'],
#  ['extremely',
#   'impressed',
#   '#34',
#   '#34',
#   '#34',
#   'cant',
#   'tell',
#   'even',
#   'works',
#   'great',
#   'didnt',
#   'come',
#   'wasnt',
#   'anything',
#   'like',
#   'sound',
#   'quality',
#   'see',
#   'bose',
#   'great',
#   'family',
#   'easy',
#   'use',
#   'learning',
#   'voice',
#   'amazon',
#   'wait',
#   'get',
#   'lot',
#   'fun',
#   'even',
#   'speaker',
#   'let',
#   'alone',
#   'plan'],
#  ['love', 'echo', 'show', 'bedroom', 'wonderful', 'music', 'info', 'sounds'],
#  ['awesome',
#   'life',
#   'able',
#   'start',
#   'morning',
#   'alexa',
#   '#34',
#   'alarm',
#   'playing',
#   'music',
#   'gotten',
#   'used',
#   'voice',
#   'another',
#   'room',
#   '#34',
#   'say',
#   'love',
#   'echos',
#   'dont',
#   'get',
#   'price',
#   'speaker',
#   'buying',
#   'take',
#   'echo',
#   'love',
#   'purchase',
#   'love',
#   'alexa'],
#  ['super',
#   'impressed',
#   'alexa',
#   'prime',
#   'wouldnt',
#   'play',
#   'anything',
#   'isnt',
#   'smart',
#   'enough',
#   'spotify',
#   'cant',
#   'use',
#   'either',
#   'talking',
#   'today',
#   'sure',
#   'ill',
#   'ever',
#   'use',
#   'alexa'],
#  ['like', 'everything'],
#  ['liked', '100'],
#  ['never',
#   'issue',
#   'buying',
#   'use',
#   'long',
#   'get',
#   'good',
#   'like',
#   'new',
#   'read',
#   'see',
#   'used'],
#  ['family', 'really', 'loves', 'new', 'echo'],
#  ['wife', 'loves'],
#  ['fun', 'got', 'today', 'go', 'use', 'house'],
#  ['like'],
#  ['third',
#   'echo',
#   'worth',
#   'every',
#   'like',
#   '3',
#   'household',
#   'small',
#   'keep',
#   'living',
#   'room',
#   'use',
#   'intercom',
#   'listen',
#   'music',
#   'answer',
#   'quick',
#   'questions',
#   'alarms',
#   'wake',
#   'etc'],
#  ['listen', 'music', 'set', 'timer'],
#  ['received',
#   'echo',
#   'perfect',
#   'device',
#   'easy',
#   'set',
#   'responds',
#   'quickly',
#   'issues',
#   'alexa',
#   'great',
#   'addition',
#   'family'],
#  ['good', 'sound', 'like', 'music', 'like', 'get', 'think', 'jokes'],
#  ['purchased',
#   'beginning',
#   'learn',
#   'far',
#   'pleased',
#   'amazed',
#   'different',
#   'enjoying',
#   'looking',
#   'forward',
#   'learning',
#   'options'],
#  ['echo', 'great', 'others', 'even', 'though', 'smaller'],
#  ['buy',
#   'something',
#   'looks',
#   'fun',
#   'totally',
#   'useful',
#   'part',
#   'home',
#   'loving'],
#  ['replace',
#   '#34',
#   'living',
#   'room',
#   'speaker',
#   'better',
#   'better',
#   'tv',
#   'unfortunately',
#   'doesnt',
#   'understand',
#   'respond',
#   'requests',
#   'well',
#   'request',
#   '2',
#   '3',
#   'times',
#   'get',
#   'want',
#   'exactly',
#   'want',
#   'first',
#   'request',
#   'dont'],
#  ['good',
#   'experience',
#   'far',
#   'second',
#   'generation',
#   'echo',
#   'many',
#   'things',
#   'learn',
#   'time',
#   'yet',
#   'right',
#   'mostly',
#   'enjoying',
#   'music',
#   'weather',
#   'updates',
#   'using',
#   'alarm',
#   'feature',
#   'also',
#   'purchased',
#   'mini',
#   'smart',
#   'yes',
#   'excited',
#   'using'],
#  ['im',
#   'trouble',
#   'connecting',
#   'tv',
#   'im',
#   'exactly',
#   'tech',
#   'smart',
#   'im',
#   'sure',
#   'figure',
#   'far',
#   'ive',
#   'using',
#   'mostly',
#   'music'],
#  ['simply',
#   'love',
#   'echo',
#   'watch',
#   'tv',
#   'im',
#   'listening',
#   'music',
#   'speaker',
#   'pretty',
#   'size',
#   'fun',
#   'skills',
#   'really',
#   'make',
#   'echo',
#   'fun',
#   'whole',
#   'family'],
#  ['enjoyed', 'echo', 'experience'],
#  ['easy', 'set'],
#  ['echo',
#   'amazing',
#   'device',
#   'many',
#   'times',
#   'seems',
#   'intuitive',
#   'times',
#   'ask',
#   'something',
#   'seems',
#   'clear',
#   'simple',
#   'get',
#   'installation',
#   'several',
#   'times',
#   'simply',
#   'thought',
#   'step',
#   'wasnt',
#   'actually',
#   'made',
#   'figured',
#   'app',
#   'let',
#   'know',
#   'next',
#   'issue',
#   'several',
#   'echo',
#   'devices',
#   'home',
#   'would',
#   'like',
#   'use',
#   'told',
#   'done',
#   'however',
#   'cant',
#   'make',
#   'echos',
#   'others',
#   'ask',
#   'alexa',
#   'answers',
#   'instructions',
#   'change',
#   'name',
#   'know',
#   'fault',
#   'would',
#   'think',
#   'would',
#   'make',
#   'easier',
#   'find',
#   'needed',
#   'instructions',
#   'small',
#   'deal',
#   'many',
#   'device',
#   'savvy',
#   'people'],
#  ['loving', 'much'],
#  ['original',
#   'alexa',
#   'far',
#   '2nd',
#   'generation',
#   'best',
#   'im',
#   'happy',
#   'see',
#   'making',
#   'new',
#   'would',
#   'great',
#   'updates',
#   'little',
#   'think',
#   'would',
#   'help',
#   'lot',
#   'happy',
#   'play',
#   'music',
#   'throughout',
#   'whole',
#   'house',
#   'bass',
#   'thank'],
#  ['pleased',
#   'echo',
#   '2nd',
#   'generation',
#   'nice',
#   'alexa',
#   'available',
#   'music',
#   'weather',
#   'news',
#   'probably',
#   'lot',
#   'havent',
#   'discovered'],
#  ['surprised',
#   'sound',
#   'quality',
#   'echo',
#   'big',
#   'fan',
#   'bass',
#   'might',
#   'though',
#   'potential',
#   'control',
#   'home',
#   'option',
#   'home',
#   'smart',
#   'home',
#   'voice',
#   'recognition',
#   'fun',
#   'purchase',
#   'great',
#   'people',
#   'ask',
#   'play',
#   'song',
#   'movie',
#   'responds',
#   'loved',
#   'would',
#   'great',
#   'gift',
#   'connected',
#   'wifi',
#   'simple',
#   'use',
#   'want',
#   'music',
#   'control',
#   'sure',
#   'amazon',
#   'prime',
#   'spotify',
#   'away',
#   'personal',
#   'even',
#   'echo',
#   'say',
#   'echo',
#   'made',
#   'couple',
#   'times',
#   'ask',
#   'tell',
#   'tells',
#   'since',
#   'amazon',
#   'prime',
#   'comes',
#   'extremely',
#   'handy'],
#  ['easy', 'setup', 'love', 'things'],
#  ['alexa', 'throughout', 'future', 'arrived'],
#  ['already',
#   'alexa',
#   'amazon',
#   'find',
#   'today',
#   'could',
#   'getting',
#   'echo',
#   'also',
#   'best',
#   'ever',
#   'use',
#   'house',
#   'couldnt'],
#  ['arrived', 'expected'],
#  ['weeks',
#   'ago',
#   'everything',
#   'product',
#   'excellent',
#   'dont',
#   'buy',
#   'must',
#   'take',
#   'outside',
#   'put'],
#  [],
#  ['love', 'echo'],
#  ['smaller', 'original', 'looks'],
#  ['works', 'great'],
#  ['husband',
#   'would',
#   'call',
#   '#34',
#   'come',
#   'technology',
#   'would',
#   'try',
#   'echo',
#   'music',
#   'amazed',
#   'great',
#   'sound',
#   'weve',
#   'also',
#   'great',
#   'time',
#   'listening',
#   'favorite',
#   'songs',
#   'buy',
#   'asking',
#   'alexa',
#   'may',
#   'even',
#   'buy',
#   'dad',
#   'think',
#   'enjoy',
#   'listen',
#   'music',
#   'even',
#   'calls',
#   'us'],
#  ['really',
#   'enjoyed',
#   'channels',
#   'plays',
#   'pandora',
#   'thermostat',
#   'turns',
#   'living',
#   'room',
#   'lights',
#   'outside',
#   'lights'],
#  ['prime', 'day', 'absolutely', 'love'],
#  ['glad',
#   'got',
#   'echo',
#   'bluetooth',
#   'speaker',
#   'alexa',
#   'much',
#   'stuff',
#   'smart',
#   'speakers',
#   'love',
#   'timer',
#   'feature',
#   'cooking',
#   'multiple',
#   'things',
#   'pandora',
#   'another',
#   'feature',
#   'use',
#   'daily',
#   'happy',
#   'prime',
#   'day',
#   'purchase',
#   'get',
#   'echo',
#   'hub',
#   'echo',
#   'dots',
#   'future'],
#  ['see', 'love'],
#  ['love'],
#  ['easy', 'setup'],
#  ['buy',
#   'echo',
#   'echo',
#   'seems',
#   'good',
#   'enough',
#   'echo',
#   'except',
#   'sound',
#   'quality',
#   'really',
#   'didnt',
#   'feel',
#   'needed',
#   'however',
#   'glad',
#   'got',
#   'difference',
#   'sound',
#   'really',
#   'far',
#   'echo',
#   'listen',
#   'little',
#   'power'],
#  ['sound', 'quality', 'great', 'learning', 'different', 'things', 'fun'],
#  ['got',
#   'good',
#   'deal',
#   'works',
#   'great',
#   'prime',
#   'setup',
#   'bit',
#   'fault',
#   'internet',
#   'service',
#   'worked',
#   'great',
#   'nice',
#   'sound',
#   'small',
#   'speaker'],
#  ['love'],
#  ['works', 'great', 'perfect', 'office'],
#  ['love', 'house', 'good', 'bose', 'speakers', 'around', 'house'],
#  ['easy'],
#  ['nice', 'product'],
#  ['love',
#   'echo',
#   'totally',
#   'amazed',
#   'speaker',
#   'quality',
#   'didnt',
#   'buy',
#   'two',
#   'since',
#   'got',
#   'prime',
#   'day'],
#  ['responsive', 'great', 'sound', 'quality', 'size'],
#  ['amazing', 'cool', 'use', 'often', 'every', 'day'],
#  ['im',
#   'impressed',
#   'quality',
#   'sound',
#   'echo',
#   'definitely',
#   'bose',
#   'mini',
#   'gave',
#   '4',
#   'stars',
#   'cant',
#   'use',
#   'apple',
#   'music',
#   'account'],
#  ['technology',
#   'small',
#   'device',
#   'price',
#   'good',
#   'sound',
#   'amazing',
#   'must',
#   'feature',
#   'home'],
#  ['mainly',
#   'use',
#   'music',
#   'im',
#   'learning',
#   'time',
#   'really',
#   'nothing',
#   'bad',
#   'say'],
#  ['replaced',
#   '1st',
#   'gen',
#   'smaller',
#   'unit',
#   'wrong',
#   'anything',
#   'volume',
#   'clear',
#   'good',
#   'product'],
#  ['great', 'addition', 'echo', 'plus'],
#  ['best'],
#  ['love', 'feature', 'play', 'music', 'every', 'room', 'multiple', 'echos'],
#  ['love', 'alexa', 'surprised', 'much', 'use'],
#  ['use', 'product', 'love'],
#  ['easy', 'use', 'great', 'great', 'purchase', 'great', 'price'],
#  ['easy', 'set', 'issues'],
#  ['unit',
#   'add',
#   'much',
#   'echo',
#   'plus',
#   'music',
#   'information',
#   'home',
#   'room'],
#  ['extremely',
#   'useful',
#   'simple',
#   'things',
#   'like',
#   'spotify',
#   'audible',
#   'things',
#   'like',
#   'doesnt',
#   'answer',
#   'everything',
#   'ask',
#   'nice',
#   'use'],
#  ['difficult', 'set', 'keeps'],
#  ['getting',
#   'use',
#   'using',
#   'echo',
#   'used',
#   'shopping',
#   'lists',
#   'listening',
#   'music',
#   'timer',
#   'working',
#   'great',
#   'far'],
#  ['cool', 'lots', 'fun', 'used', 'week', 'learning', 'capabilities'],
#  ['love', 'love'],
#  ['love', 'hard', 'time', 'setting', 'apps'],
#  ['use', 'office', 'another', 'music', 'information'],
#  ['great', 'music', 'little', 'hard', 'figure', 'works'],
#  ['given',
#   'year',
#   'time',
#   'birthday',
#   'gift',
#   'dad',
#   'loves',
#   'ask',
#   'alexa',
#   'anything',
#   'answer',
#   'plus',
#   'good',
#   'purchased',
#   'prime',
#   'day',
#   'bathroom',
#   'im',
#   'getting',
#   'ready',
#   'work',
#   'listen',
#   'music',
#   'base',
#   'replacement',
#   'clock',
#   'radio',
#   'plus',
#   'echo',
#   'night',
#   'stand',
#   'alarm',
#   'clock'],
#  ['impressed', 'look', 'sound', 'color'],
#  ['alexa', 'amazing', 'great', 'speaker'],
#  ['getting',
#   'used',
#   'alexa',
#   'dont',
#   'connected',
#   'tv',
#   'yet',
#   'things',
#   'right',
#   'use',
#   'music',
#   'information',
#   'great'],
#  ['works',
#   'sounds',
#   'great',
#   'house',
#   'kitchen',
#   'hear',
#   'speak',
#   'room',
#   'lots',
#   'functionality'],
#  ['fun',
#   'echo',
#   'weather',
#   'jokes',
#   'news',
#   'briefing',
#   'music',
#   'much',
#   'use',
#   'lot',
#   'fun',
#   'money'],
#  ['use', 'time', 'especially', 'kids', 'throughout', 'home'],
#  ['love',
#   'learning',
#   'makes',
#   'lot',
#   'things',
#   'easier',
#   'like',
#   'turn',
#   'light',
#   'another',
#   'room',
#   'ask',
#   'alexa',
#   'turn',
#   'light'],
#  ['daughter',
#   'turned',
#   'loves',
#   'especially',
#   'like',
#   'calling',
#   'feature',
#   'since',
#   'doesnt',
#   'cell',
#   'phone',
#   'loves',
#   'playing',
#   'music',
#   'amazon',
#   'music',
#   'play',
#   'favorite',
#   'songs',
#   'lol'],
#  ['got',
#   'gift',
#   'havent',
#   'discovered',
#   'features',
#   'yet',
#   'update',
#   'playing',
#   'music',
#   'great',
#   'though'],
#  ['impressed', 'sound', 'quality'],
#  ['pleased',
#   'purchase',
#   'echo',
#   'smart',
#   'speaker',
#   'love',
#   'fact',
#   'play',
#   'music',
#   'different',
#   'trouble',
#   'first',
#   'working'],
#  ['wife',
#   'enjoy',
#   'ease',
#   'playing',
#   'music',
#   'games',
#   'fun',
#   'look',
#   'forward',
#   'adding',
#   'smart',
#   'products',
#   'home'],
#  ['second',
#   'echo',
#   'love',
#   'helps',
#   'kitchen',
#   'set',
#   'timers',
#   'listen',
#   'news',
#   'grocery',
#   'lists',
#   'get',
#   'great',
#   'music'],
#  ['sound', 'quality', 'good', 'wish', 'alexa', 'could', 'answer', 'questions'],
#  ['second',
#   'echo',
#   'speaker',
#   'purchased',
#   'listening',
#   'music',
#   'speaker',
#   'great'],
#  ['great', 'sound'],
#  ['great'],
#  ['really', 'use', 'speaker', 'stream', 'music', 'weve', 'months', 'useless'],
#  ['set',
#   'user',
#   'friendly',
#   'setup',
#   'wasnt',
#   'user',
#   'friendly',
#   'id',
#   'alexa',
#   'app',
#   'able',
#   'download',
#   'wife',
#   'wouldnt',
#   'able',
#   'install',
#   'alexa',
#   'son',
#   'wasnt',
#   'smart',
#   'phone',
#   'wouldnt',
#   'using',
#   'alexa',
#   'yet'],
#  ['easy', 'set', 'really', 'enjoying'],
#  ['echo',
#   'doesnt',
#   'come',
#   'built',
#   'battery',
#   'plugged',
#   'times',
#   'use',
#   'makes',
#   'quite'],
#  ['bit', 'better', 'original'],
#  ['love', 'pretty', 'cool'],
#  ['living',
#   'room',
#   'music',
#   'sounds',
#   'really',
#   'good',
#   'living',
#   'room',
#   'hear',
#   'upstairs'],
#  ['great', 'product', 'set', 'easy', 'sound', 'wonderful'],
#  ['far', 'like', 'music', 'though', 'sounds', 'pretty', 'good'],
#  ['love'],
#  ['love'],
#  ['glad'],
#  ['like', 'fun', 'music'],
#  ['like', 'volume', 'top', 'turn', 'quickly'],
#  ['capabilities', 'program', 'grandkids'],
#  ['love',
#   'new',
#   'echo',
#   'gives',
#   'hours',
#   'music',
#   'help',
#   'difficult',
#   'set',
#   'help'],
#  ['almost', 'good', 'bose', 'love', 'whole', 'house', 'music'],
#  ['alexa', 'came'],
#  ['easy',
#   'setup',
#   'using',
#   'app',
#   'also',
#   'easy',
#   'install',
#   'phone',
#   'sound',
#   'quality',
#   'listening',
#   'music',
#   'pandora',
#   'wonderful'],
#  ['im', 'learning', 'use', 'echo', 'far', 'love'],
#  ['works', 'awesome'],
#  ['works', 'great'],
#  ['small', 'speaker', 'sounds', 'great'],
#  ['great', 'sound', 'size'],
#  ['dont', 'echo', 'definitely', 'need'],
#  ['great', 'device', 'seems', 'work', 'better', '1st', 'generation'],
#  ['longer',
#   'works',
#   '5',
#   'months',
#   'use',
#   'connect',
#   'wifi',
#   'reset',
#   'requests'],
#  ['love',
#   'echo',
#   'easy',
#   'fun',
#   'get',
#   'drop',
#   'lives',
#   'away',
#   'sounds',
#   'like',
#   'right',
#   'next'],
#  ['works', 'great', 'different', 'new', 'ones'],
#  ['ones', 'going', 'kitchen', 'timer', 'music'],
#  ['love',
#   'volume',
#   'could',
#   'definitely',
#   'use',
#   'better',
#   'built',
#   'speakers',
#   'would',
#   '5',
#   'star',
#   'thought',
#   'put',
#   'audio',
#   'speaker',
#   'echo',
#   'best',
#   'way',
#   'go'],
#  ['works', 'fine'],
#  ['works',
#   'great',
#   'looks',
#   'brand',
#   'new',
#   'love',
#   'new',
#   'echo',
#   'getting',
#   'rooms',
#   'house'],
#  ['refurbished',
#   'works',
#   'like',
#   'new',
#   'love',
#   'easy',
#   'set',
#   'love',
#   'issue',
#   'volume',
#   'listening',
#   'fine',
#   'expecting',
#   'anything',
#   'else',
#   'recommend',
#   'purchasing',
#   'speaker'],
#  ['loud'],
#  ['2nd', 'love'],
#  ['sure',
#   'feel',
#   'echo',
#   'many',
#   'things',
#   'need',
#   'get',
#   'used',
#   'ask',
#   'right',
#   'questions',
#   'wont',
#   'understand'],
#  ['works',
#   '3rd',
#   'apps',
#   'stuff',
#   'think',
#   'could',
#   'box',
#   'im',
#   'back',
#   'money'],
#  ['gift',
#   'doesnt',
#   'like',
#   'plug',
#   'show',
#   'cord',
#   'would',
#   'works',
#   'though'],
#  ['amazon',
#   'echo',
#   'device',
#   'purchased',
#   'refurbished',
#   'satisfied',
#   'time',
#   'different',
#   'cant',
#   'tell',
#   'brand',
#   'new',
#   'price',
#   '10',
#   'echos',
#   'wake',
#   'us',
#   'keep',
#   'timers',
#   'play',
#   'music',
#   'us',
#   'turn',
#   'lights',
#   'much'],
#  ['small', 'echo', 'amazing', 'sounds', 'come', 'thermostat', 'hue'],
#  ['talk', 'time', 'songs', 'device'],
#  ['im', 'never', 'disappointed', 'technology'],
#  ['worked'],
#  ['2',
#   'echo',
#   'dots',
#   'getting',
#   '1',
#   '2',
#   'package',
#   'want',
#   'package',
#   'see'],
#  ['working'],
#  ['echo', 'devices'],
#  ['sure', 'love', 'alexa', 'lol', 'thank', 'great', 'price', 'product'],
#  ['works'],
#  ['im', 'echo', 'fan', 'work'],
#  [],
#  ['bathroom', 'listen', 'im', 'love'],
#  ['doesnt',
#   'always',
#   'respond',
#   'thought',
#   'would',
#   'connect',
#   'echo',
#   'upstairs',
#   'use',
#   'like',
#   'intercom',
#   'havent',
#   'able'],
#  ['fast', 'works', 'well'],
#  ['love'],
#  ['love', 'love', 'love', 'new', 'free', 'assistant'],
#  ['words', '#34', 'alexa', 'tell'],
#  ['worked',
#   'stopped',
#   'ive',
#   'tried',
#   'everything',
#   'try',
#   'make',
#   'work',
#   'nothing',
#   'working',
#   'want'],
#  ['quality', 'gave', 'away'],
#  ['refurbished', 'way', 'go', 'echo', 'works', 'like', 'new'],
#  ['love'],
#  ['need', 'say'],
#  ['speakers', 'loud', 'alexa', 'great', 'though'],
#  ['works', 'great', 'sounds', 'good'],
#  ['never',
#   'could',
#   'get',
#   'work',
#   'friend',
#   'said',
#   'adapter',
#   'wasnt',
#   'enough',
#   'power',
#   'like',
#   'going',
#   'replace',
#   'adapter',
#   'works'],
#  ['almost', 'like', 'star', 'home', 'fun', 'try'],
#  ['add', 'echo', 'system', 'refurbished', 'product', 'works', 'like', 'new'],
#  ['great', 'office', 'use', 'daily', 'many', 'ways', 'music'],
#  ['awesome', 'love', 'alexa'],
#  ['wasnt', 'sure', 'really', 'wanted', 'extremely', 'useful', 'get', 'love'],
#  ['echo',
#   'worked',
#   'well',
#   'time',
#   'stopped',
#   'alexa',
#   'unless',
#   'within',
#   'echos',
#   'echo',
#   'dots',
#   'rooms',
#   'would',
#   'respond',
#   'response',
#   'echo',
#   'would',
#   'recommend',
#   'buying',
#   'refurbished'],
#  ['great', 'product', 'fast'],
#  ['echo',
#   'refurbished',
#   'stops',
#   'quite',
#   'often',
#   'doesnt',
#   'wake',
#   'every',
#   'time',
#   'turns',
#   'nothing',
#   'buy',
#   'refurbished',
#   'echo'],
#  ['perfect', 'works', 'great', 'problems', 'refurbished'],
#  ['dont'],
#  ['perfect', 'love', 'echo'],
#  ['love', 'experience', 'especially', 'hooked', 'smart'],
#  ['got',
#   'within',
#   'last',
#   'couple',
#   'weeks',
#   'tell',
#   'issues',
#   'son',
#   'wanted',
#   '#34',
#   'birthday',
#   'could',
#   'tell',
#   'jokes',
#   'could',
#   'ask',
#   'questions',
#   'listen',
#   'music',
#   'enjoy',
#   'much',
#   'second',
#   'week',
#   'prime',
#   'day'],
#  [],
#  ['great', 'product', 'works', 'great'],
#  ['room', 'radio', 'alarm', 'clock', 'information', 'much'],
#  ['great',
#   'buy',
#   'go',
#   'echo',
#   'love',
#   'speaker',
#   'isnt',
#   'best',
#   'music',
#   'works',
#   'great',
#   'kitchen',
#   'timers',
#   'alarms'],
#  [],
#  ['works', 'perfect', 'save', 'buy', 'refurbished', 'looks', 'brand', 'new'],
#  ['looks', 'works', 'perfect', 'glad', 'got', 'good', 'deal'],
#  ['good', 'new', 'less'],
#  ['love', 'works', 'well'],
#  ['everything', 'perfect'],
#  ['good', 'price', 'working'],
#  ['love', 'alexa'],
#  ['theres',
#   'room',
#   'improvement',
#   'price',
#   'cannot',
#   'much',
#   'however',
#   'audio',
#   'terrible',
#   'kind',
#   'like',
#   'listening'],
#  ['son', 'wanted', 'awesome'],
#  ['echo',
#   'works',
#   'price',
#   'great',
#   'deal',
#   'issues',
#   'dots',
#   'speaker',
#   'bit',
#   'good',
#   'second',
#   'unit',
#   'like',
#   'external',
#   'speaker',
#   'buy'],
#  ['thanks'],
#  ['wanted',
#   'use',
#   'radio',
#   'intercom',
#   'get',
#   'terrible',
#   'live',
#   'recognition',
#   'software',
#   'wife',
#   'language',
#   'yet',
#   'good',
#   'job',
#   'us',
#   'two',
#   'wifi',
#   'buy',
#   'wifi',
#   'range',
#   'office',
#   'problems',
#   'around',
#   'difference'],
#  ['third',
#   'work',
#   'perfectly',
#   'use',
#   'multiple',
#   'times',
#   'day',
#   'absolutely',
#   'love'],
#  ['never',
#   'worked',
#   'box',
#   'several',
#   'days',
#   'trying',
#   'get',
#   'working',
#   'running',
#   '#34',
#   'amazon',
#   'never',
#   'order',
#   'another',
#   'refurbished',
#   'device'],
#  ['already', 'echo', 'plus', 'bedroom', 'love', 'functions'],
#  ['simple', 'set', 'music'],
#  ['worked', 'like', 'brand', 'new', 'satisfied'],
#  ['great',
#   'product',
#   'new',
#   'alexa',
#   'refurbished',
#   'already',
#   'problems',
#   'connection'],
#  ['echos',
#   'already',
#   'went',
#   'refurbished',
#   'save',
#   'works',
#   'great',
#   'love',
#   'new',
#   'generation',
#   'nice'],
#  ['love', 'fact', 'take', 'want'],
#  ['refurbished', 'good', 'new', 'ones', 'ive'],
#  ['good', 'new'],
#  ['loves'],
#  ['price',
#   'great',
#   'trouble',
#   'hearing',
#   'across',
#   'room',
#   'another',
#   'spot',
#   'seems',
#   'working',
#   'fine',
#   'buy',
#   'want',
#   '1',
#   'every',
#   'room'],
#  ['set',
#   'alexa',
#   'blue',
#   'tooth',
#   'speakers',
#   'enjoy',
#   'listening',
#   'music',
#   'cant',
#   'wait',
#   'try',
#   'new',
#   'stuff',
#   'using',
#   'alexa'],
#  ['thanks'],
#  ['works', 'great'],
#  ['#34',
#   'never',
#   'buy',
#   'refurbished',
#   'echo',
#   '#34',
#   '#34',
#   'refurbished',
#   '#34',
#   'echo',
#   'unit',
#   'command',
#   'even',
#   'command',
#   'never',
#   'buy',
#   'refurbished',
#   'echo',
#   'unit',
#   'received',
#   'probably',
#   'never',
#   'refurbished',
#   'also',
#   'new',
#   'echo',
#   'works',
#   'disappointed'],
#  ['started',
#   'amazon',
#   'regret',
#   'nothing',
#   'absolutely',
#   'great',
#   'products',
#   'continue',
#   'improve',
#   'life'],
#  ['used', 'several', 'months', 'problem'],
#  ['first', 'smart', 'device', 'buying', 'devices', 'compatible'],
#  ['love'],
#  ['love', 'good', 'new'],
#  ['larger',
#   'echo',
#   'time',
#   'love',
#   'another',
#   'house',
#   'since',
#   'several',
#   'wifi',
#   'home',
#   'devices',
#   'wanted',
#   'voice',
#   'control',
#   'house'],
#  ['love', 'product', 'use', 'turn', 'lights', 'answer', 'quick', 'questions'],
#  ['great', 'buy'],
#  ['refurbished', 'work', 'great'],
#  ['sound', 'works', 'great'],
#  ['great'],
#  ['exactly',
#   'like',
#   'new',
#   'tell',
#   'difference',
#   'new',
#   'got',
#   'works',
#   'perfectly',
#   'love',
#   'alexa'],
#  ['works',
#   'perfect',
#   'device',
#   'love',
#   'alexa',
#   'working',
#   'making',
#   'home',
#   'smart'],
#  ['works', 'good'],
#  ['dont', 'like', 'works', 'great'],
#  ['excellent',
#   'product',
#   'refurbished',
#   'unit',
#   'would',
#   'never',
#   'know',
#   'refurbished'],
#  ['already',
#   'couple',
#   'echos',
#   'couldnt',
#   'also',
#   'use',
#   'finally',
#   'amazon',
#   'feature',
#   'use',
#   'echos',
#   'family',
#   'remote',
#   'house',
#   'never',
#   'heard',
#   'come',
#   'features',
#   'mainly',
#   'use',
#   'echos',
#   'stuff',
#   'playing',
#   'music',
#   'setting',
#   'alarms',
#   'questions',
#   'etc',
#   'home',
#   'device',
#   'amazon',
#   'would',
#   'convenient',
#   'around',
#   'looks',
#   'works',
#   'ones'],
#  ['love',
#   'refurbished',
#   'part',
#   'first',
#   'first',
#   'echo',
#   'awesome',
#   'used',
#   'everything',
#   'lights',
#   'since',
#   'work',
#   'shopping',
#   'well',
#   'spotify',
#   'getting',
#   'parents',
#   'help',
#   'things',
#   'take',
#   'would',
#   'recommend'],
#  ['love', 'alexa', 'every', 'room', 'soon'],
#  ['use', 'setting'],
#  ['great', 'got', 'upstairs'],
#  ['works', 'great', 'never', 'issues'],
#  ['everything', 'asked'],
#  ['works', 'great', 'good', 'sound'],
#  ['use',
#   'echo',
#   'listen',
#   'music',
#   'well',
#   'tool',
#   'answer',
#   'questions',
#   'would',
#   'like',
#   'volume',
#   'could',
#   'go',
#   'little',
#   'bit',
#   'louder',
#   'cant',
#   'also',
#   'power',
#   'order',
#   'use',
#   'echo',
#   'must',
#   'plugged',
#   'times',
#   'using',
#   'cord',
#   'would',
#   'nice',
#   'use',
#   'echo',
#   'go',
#   'buy',
#   'product'],
#  ['love', 'great', 'fun'],
#  ['love'],
#  ['use', 'like', 'say'],
#  ['10',
#   'always',
#   'nice',
#   'son',
#   'always',
#   'says',
#   'buying',
#   'refurbished',
#   'getting',
#   'new',
#   'device',
#   'product',
#   'less',
#   'run',
#   'everything'],
#  ['works', 'perfectly', 'alexa', 'turns', 'lights', 'tv'],
#  ['never', 'would', 'know', 'refurbished'],
#  ['far', 'good'],
#  ['looks', 'new', 'complaints'],
#  ['goes', 'great', 'echo'],
#  ['works', 'great', 'like', 'new', 'already'],
#  ['work',
#   'refurbished',
#   'works',
#   'advertised',
#   'instead',
#   'soon',
#   'turned',
#   'plugged',
#   'trying',
#   'connect',
#   'phone',
#   'echo',
#   'would',
#   'light',
#   'would',
#   'would',
#   'blue',
#   'light',
#   'alexa',
#   'would',
#   'tell',
#   'ready',
#   'connect',
#   'tried',
#   '5',
#   'didnt',
#   'anything',
#   'immediately',
#   'actually',
#   'fix',
#   'next'],
#  ['fast', 'service', 'got', 'ordered', 'thank'],
#  ['love',
#   'even',
#   'though',
#   'im',
#   'trying',
#   'figure',
#   'things',
#   'works',
#   'great',
#   'phone'],
#  [],
#  ['2',
#   'echos',
#   'brand',
#   'new',
#   'refurbished',
#   'cant',
#   'tell',
#   'difference',
#   'looks'],
#  ['great', 'work', 'awesome'],
#  ['works'],
#  ['work', 'time'],
#  ['love', 'though', 'wish'],
#  [],
#  ['could',
#   'tell',
#   'refurbished',
#   'works',
#   'excellent',
#   'would',
#   'highly',
#   'instead',
#   'purchasing',
#   'new'],
#  ['got', 'mom', 'loves'],
#  ['love', 'echo', 'looks', 'brand', 'new', 'works', 'perfect', 'satisfied'],
#  ['new'],
#  ['small',
#   'problem',
#   'box',
#   'amazon',
#   'reset',
#   'process',
#   'issues',
#   'get',
#   'response',
#   'quickly',
#   'real',
#   'made',
#   'get',
#   'working',
#   'google',
#   'use',
#   'learn',
#   'like',
#   'also',
#   'plan',
#   'install',
#   'alexa',
#   'new',
#   'best',
#   'friend',
#   'lol',
#   'think',
#   'alexa',
#   'time',
#   'limited'],
#  ['love',
#   'alexa',
#   'play',
#   'games',
#   'son',
#   'ask',
#   'weather',
#   'love',
#   'works',
#   'amazon',
#   'fire',
#   'tv'],
#  ['like',
#   'could',
#   'ask',
#   'different',
#   'questions',
#   'different',
#   'things',
#   'works',
#   'smart',
#   'tv',
#   'ask',
#   'change',
#   'volume',
#   'ask',
#   'change',
#   'doesnt',
#   'reset',
#   'dont',
#   'know',
#   'refurbished',
#   'expected'],
#  ['far',
#   'refurbished',
#   'echo',
#   'works',
#   'well',
#   'little',
#   'ring',
#   'echo',
#   '100',
#   'know',
#   'asked',
#   'alexa',
#   'said',
#   'call',
#   'drop',
#   'took',
#   '10',
#   'minutes',
#   'figure',
#   'amazon',
#   'ring',
#   'supposed',
#   'refurbished',
#   'echo'],
#  ['arrived',
# ...
#   'sale',
#   'couldnt',
#   'beginning',
#   'smart',
#   'home',
#   'set',
#   'couldnt',
#   'say',
#   'alexa',
#   'done',
#   'amazing',
#   'job',
#   'connecting',
#   'smart',
#   'devices',
#   'thanks',
#   'control',
#   'lights',
#   'smart',
#   'plugs',
#   'tv',
#   'etc',
#   'trouble',
#   'connecting',
#   'echo',
#   'wifi',
#   'phone',
#   'app',
#   'works',
#   'perfectly',
#   'fine',
#   'lets',
#   'add',
#   'skills',
#   'smart',
#   'devices',
#   'timers',
#   'much',
#   'sound',
#   'quality',
#   'good',
#   'enough',
#   'since',
#   'alexa',
#   'hear',
#   'voice',
#   'even',
#   'watching',
#   'movies',
#   'high',
#   'volume',
#   'great',
#   'definitely',
#   'add',
#   'nice',
#   'touch',
#   'home',
#   'change',
#   'like',
#   'sale',
#   'overall',
#   'great',
#   'addition',
#   'home',
#   'many',
#   'havent',
#   'yet',
#   'sure',
#   'add',
#   'alexa',
#   'home'],
#  ['fun'],
#  ['works', 'great', 'speaker', 'wife', 'son', 'love'],
#  ['regret', 'long', 'purchase', 'surprised', 'pleased', 'sound', 'quality'],
#  ['stopped',
#   'working',
#   '2',
#   'weeks',
#   'didnt',
#   'commands',
#   'really',
#   'fun',
#   'working'],
#  ['far',
#   'love',
#   'working',
#   'getting',
#   'things',
#   'set',
#   'love',
#   'grocery',
#   'list',
#   'app'],
#  ['pretty',
#   'much',
#   'expected',
#   'disappointed',
#   'need',
#   'play',
#   'music',
#   'amazon',
#   'music',
#   'service',
#   'understand',
#   'music',
#   'choices',
#   'may',
#   'limited',
#   'ask',
#   'cannot',
#   'access',
#   'music',
#   'free',
#   'along',
#   'echo',
#   'purchase',
#   'language',
#   'need',
#   'use'],
#  ['easy', 'set'],
#  ['like', 'product', 'except', 'speakers', 'high', 'quality', 'expected'],
#  ['great', 'alexa', 'made'],
#  ['yet', 'another', 'home', 'love'],
#  ['love',
#   'plan',
#   'music',
#   'big',
#   'easy',
#   'find',
#   'radio',
#   'sound',
#   'good',
#   'stop',
#   'voice',
#   'command',
#   'get',
#   'phone',
#   'call'],
#  ['good', 'value'],
#  ['super', 'easy', 'set', 'loving', 'new', 'echo'],
#  ['whats', 'like', 'speaker', 'ask', 'alexa'],
#  ['best',
#   'day',
#   'gift',
#   'dad',
#   'mom',
#   'alexa',
#   'listening',
#   'going',
#   'forward'],
#  ['great',
#   'addition',
#   'room',
#   'kitchen',
#   'information',
#   'available',
#   'learning',
#   'features'],
#  ['sound', 'quality'],
#  [],
#  ['entertainment'],
#  ['good', 'quality'],
#  ['works', 'great', 'sounds', 'great', 'miss', 'wish', 'battery', 'better'],
#  ['loved', 'someone', 'cant', 'replace', 'yet', 'going'],
#  ['alexa'],
#  ['got',
#   'gift',
#   'love',
#   'never',
#   'would',
#   'play',
#   'music',
#   'prime',
#   'music',
#   'thats',
#   'worth',
#   'also',
#   'gives',
#   'news',
#   'tells',
#   'jokes'],
#  [],
#  ['mom',
#   'echo',
#   'dots',
#   'ask',
#   'take',
#   'great',
#   'told',
#   'two',
#   'days',
#   'made',
#   'take',
#   'hours',
#   'later',
#   'could',
#   'live',
#   'life',
#   'amazing',
#   'large',
#   'speakers',
#   'small',
#   'echo',
#   'say',
#   'youre',
#   'going',
#   'order',
#   'alexa',
#   'speaker',
#   'go',
#   'big',
#   'get',
#   'echo',
#   'two',
#   'echo',
#   'dots',
#   'couldnt',
#   'live'],
#  ['love', 'great', 'product'],
#  ['easy', 'set', 'user', 'friendly'],
#  ['really',
#   'disappointed',
#   'alexa',
#   'time',
#   'fault',
#   'checking',
#   'made',
#   'amazon',
#   'would',
#   'product',
#   'battery',
#   'could',
#   'return',
#   'would',
#   'apple',
#   'music',
#   'speaker',
#   'give',
#   'alexa'],
#  ['dont',
#   'think',
#   '#34',
#   '2nd',
#   'sounds',
#   'good',
#   '1st',
#   'could',
#   'add',
#   'external',
#   'speaker',
#   'going',
#   'wouldnt',
#   'get',
#   '2nd',
#   'issue',
#   'isnt',
#   'unit',
#   'dont',
#   'understand',
#   'cant',
#   'playing',
#   'blue',
#   'tooth',
#   'speaker',
#   'playing',
#   '#34',
#   'get',
#   'using',
#   'speaker',
#   'units',
#   'heard',
#   'able',
#   'play',
#   'group',
#   'using',
#   'speaker'],
#  ['everything'],
#  ['like',
#   'asking',
#   'questions',
#   'dont',
#   'like',
#   'cant',
#   'ask',
#   'setup',
#   'connected',
#   'lamp'],
#  ['sound', 'definitely', 'worth', 'extra', 'money', 'listen', 'lots', 'music'],
#  ['really',
#   'love',
#   'amazon',
#   'echo',
#   'think',
#   'sound',
#   'quality',
#   'great',
#   'lot',
#   'fun',
#   'really',
#   'handy',
#   'music',
#   'get',
#   'updates',
#   'weather'],
#  ['love', 'grandkids'],
#  ['far',
#   'worked',
#   'well',
#   'always',
#   'intuitive',
#   'link',
#   'different',
#   'devices',
#   'skills',
#   'getting'],
#  ['works', 'advertised'],
#  ['love'],
#  ['love',
#   'new',
#   'addition',
#   'house',
#   'speaker',
#   'quality',
#   'great',
#   'love',
#   'alexa',
#   'two',
#   'complaints',
#   'future',
#   'would',
#   'better',
#   'ability',
#   'smart',
#   'lights',
#   'house',
#   'unless',
#   'kitchen',
#   'light',
#   '1',
#   'kitchen',
#   'light',
#   '2',
#   'command',
#   'either',
#   'wont',
#   'respond',
#   'says',
#   'doesnt',
#   'may',
#   'want',
#   'alexa',
#   'respond',
#   'say',
#   'thank',
#   'alexa',
#   'thank',
#   'times',
#   'wont',
#   'respond',
#   'husband',
#   'know',
#   'sounds',
#   'want',
#   'alexa'],
#  ['like', 'everything', 'music', 'games', 'weather'],
#  ['received', 'time', 'like', 'music'],
#  ['great', 'device'],
#  ['echo',
#   'year',
#   'new',
#   'easy',
#   'way',
#   'volume',
#   'telling',
#   'volume',
#   'hard',
#   'wife',
#   'since',
#   'second',
#   'language',
#   'sound',
#   'echo',
#   'well',
#   'keep'],
#  ['love', 'kitchen', 'works', 'well'],
#  ['nice', 'im', 'impressed', 'wish', 'say', 'though'],
#  ['love', 'product', 'nice', 'easy', 'access', 'much', 'info'],
#  ['got', 'great', 'sound', 'bass', 'doesnt', 'work', 'time', 'miss', 'things'],
#  ['echo'],
#  ['amazing'],
#  ['good',
#   'hearing',
#   'range',
#   'sound',
#   'quality',
#   'bit',
#   'set',
#   'doesnt',
#   'quite',
#   'understand',
#   'lot',
#   'even',
#   'clearly',
#   'love',
#   'flash',
#   'briefing',
#   'feature',
#   'home',
#   'security',
#   'system'],
#  ['speaker', 'sounds', 'good'],
#  ['absolutely', 'love'],
#  ['best',
#   'part',
#   'product',
#   'control',
#   'thermostat',
#   'lights',
#   'house',
#   'isnt',
#   'anything',
#   'dislike'],
#  ['enjoying',
#   'amazon',
#   'echo',
#   'installation',
#   'easy',
#   'using',
#   'alexa',
#   'app',
#   'purchased',
#   '2',
#   'kasa',
#   'smart',
#   'plugs',
#   'control',
#   'living',
#   'room',
#   'lights',
#   'installation',
#   'easy',
#   'using',
#   'kasa',
#   'app',
#   'right',
#   'echo',
#   'enjoying',
#   'playing',
#   'music',
#   'echo',
#   'sound',
#   'quality',
#   'awesome',
#   'weve',
#   'added',
#   'kasa',
#   'smart',
#   'bulb',
#   'kitchen',
#   'setup',
#   'looking',
#   'forward',
#   'adding',
#   'automation',
#   'home'],
#  ['home', 'entertainment'],
#  ['cool',
#   'product',
#   'easy',
#   'setup',
#   'fun',
#   'use',
#   'sound',
#   'quality',
#   'much',
#   'better'],
#  ['love', 'great', 'sound', 'easy', 'connect', 'use'],
#  ['doesnt',
#   'work',
#   'new',
#   'smart',
#   'tv',
#   'thats',
#   'mainly',
#   'tv',
#   'fault',
#   'due',
#   'anything',
#   'older',
#   'year',
#   'smart',
#   'also',
#   'need',
#   'additional',
#   'piece',
#   'order',
#   'connect',
#   'well',
#   'speakers',
#   'sound',
#   'great',
#   'works',
#   'well'],
#  ['great', 'sound', 'little', 'speaker'],
#  ['enjoy'],
#  [],
#  ['cool'],
#  ['good', 'quality', 'great', 'sound', 'quality'],
#  ['works', 'perfectly'],
#  ['great',
#   'product',
#   'alexa',
#   'understand',
#   'commands',
#   'fire',
#   'tv',
#   'speaker'],
#  ['love', 'echo', 'great', 'sound', 'smart'],
#  ['sure', 'love'],
#  ['plays', 'great'],
#  ['works', 'absolutely', 'great'],
#  ['amazing', 'product', 'great', 'sound', 'quality'],
#  ['best', 'ive', 'thank', 'much'],
#  ['extremely',
#   'impressed',
#   '#34',
#   '#34',
#   '#34',
#   'cant',
#   'tell',
#   'even',
#   'works',
#   'great',
#   'didnt',
#   'come',
#   'wasnt',
#   'anything',
#   'like',
#   'sound',
#   'quality',
#   'see',
#   'bose',
#   'great',
#   'family',
#   'easy',
#   'use',
#   'learning',
#   'voice',
#   'amazon',
#   'wait',
#   'get',
#   'lot',
#   'fun',
#   'even',
#   'speaker',
#   'let',
#   'alone',
#   'plan'],
#  ['love', 'echo', 'show', 'bedroom', 'wonderful', 'music', 'info', 'sounds'],
#  ['awesome',
#   'life',
#   'able',
#   'start',
#   'morning',
#   'alexa',
#   '#34',
#   'alarm',
#   'playing',
#   'music',
#   'gotten',
#   'used',
#   'voice',
#   'another',
#   'room',
#   '#34',
#   'say',
#   'love',
#   'echos',
#   'dont',
#   'get',
#   'price',
#   'speaker',
#   'buying',
#   'take',
#   'echo',
#   'love',
#   'purchase',
#   'love',
#   'alexa'],
#  ['super',
#   'impressed',
#   'alexa',
#   'prime',
#   'wouldnt',
#   'play',
#   'anything',
#   'isnt',
#   'smart',
#   'enough',
#   'spotify',
#   'cant',
#   'use',
#   'either',
#   'talking',
#   'today',
#   'sure',
#   'ill',
#   'ever',
#   'use',
#   'alexa'],
#  ['like', 'everything'],
#  ['liked', '100'],
#  ['never',
#   'issue',
#   'buying',
#   'use',
#   'long',
#   'get',
#   'good',
#   'like',
#   'new',
#   'read',
#   'see',
#   'used'],
#  ['family', 'really', 'loves', 'new', 'echo'],
#  ['wife', 'loves'],
#  ['fun', 'got', 'today', 'go', 'use', 'house'],
#  ['like'],
#  ['third',
#   'echo',
#   'worth',
#   'every',
#   'like',
#   '3',
#   'household',
#   'small',
#   'keep',
#   'living',
#   'room',
#   'use',
#   'intercom',
#   'listen',
#   'music',
#   'answer',
#   'quick',
#   'questions',
#   'alarms',
#   'wake',
#   'etc'],
#  ['listen', 'music', 'set', 'timer'],
#  ['received',
#   'echo',
#   'perfect',
#   'device',
#   'easy',
#   'set',
#   'responds',
#   'quickly',
#   'issues',
#   'alexa',
#   'great',
#   'addition',
#   'family'],
#  ['good', 'sound', 'like', 'music', 'like', 'get', 'think', 'jokes'],
#  ['purchased',
#   'beginning',
#   'learn',
#   'far',
#   'pleased',
#   'amazed',
#   'different',
#   'enjoying',
#   'looking',
#   'forward',
#   'learning',
#   'options'],
#  ['echo', 'great', 'others', 'even', 'though', 'smaller'],
#  ['buy',
#   'something',
#   'looks',
#   'fun',
#   'totally',
#   'useful',
#   'part',
#   'home',
#   'loving'],
#  ['replace',
#   '#34',
#   'living',
#   'room',
#   'speaker',
#   'better',
#   'better',
#   'tv',
#   'unfortunately',
#   'doesnt',
#   'understand',
#   'respond',
#   'requests',
#   'well',
#   'request',
#   '2',
#   '3',
#   'times',
#   'get',
#   'want',
#   'exactly',
#   'want',
#   'first',
#   'request',
#   'dont'],
#  ['good',
#   'experience',
#   'far',
#   'second',
#   'generation',
#   'echo',
#   'many',
#   'things',
#   'learn',
#   'time',
#   'yet',
#   'right',
#   'mostly',
#   'enjoying',
#   'music',
#   'weather',
#   'updates',
#   'using',
#   'alarm',
#   'feature',
#   'also',
#   'purchased',
#   'mini',
#   'smart',
#   'yes',
#   'excited',
#   'using'],
#  ['im',
#   'trouble',
#   'connecting',
#   'tv',
#   'im',
#   'exactly',
#   'tech',
#   'smart',
#   'im',
#   'sure',
#   'figure',
#   'far',
#   'ive',
#   'using',
#   'mostly',
#   'music'],
#  ['simply',
#   'love',
#   'echo',
#   'watch',
#   'tv',
#   'im',
#   'listening',
#   'music',
#   'speaker',
#   'pretty',
#   'size',
#   'fun',
#   'skills',
#   'really',
#   'make',
#   'echo',
#   'fun',
#   'whole',
#   'family'],
#  ['enjoyed', 'echo', 'experience'],
#  ['easy', 'set'],
#  ['echo',
#   'amazing',
#   'device',
#   'many',
#   'times',
#   'seems',
#   'intuitive',
#   'times',
#   'ask',
#   'something',
#   'seems',
#   'clear',
#   'simple',
#   'get',
#   'installation',
#   'several',
#   'times',
#   'simply',
#   'thought',
#   'step',
#   'wasnt',
#   'actually',
#   'made',
#   'figured',
#   'app',
#   'let',
#   'know',
#   'next',
#   'issue',
#   'several',
#   'echo',
#   'devices',
#   'home',
#   'would',
#   'like',
#   'use',
#   'told',
#   'done',
#   'however',
#   'cant',
#   'make',
#   'echos',
#   'others',
#   'ask',
#   'alexa',
#   'answers',
#   'instructions',
#   'change',
#   'name',
#   'know',
#   'fault',
#   'would',
#   'think',
#   'would',
#   'make',
#   'easier',
#   'find',
#   'needed',
#   'instructions',
#   'small',
#   'deal',
#   'many',
#   'device',
#   'savvy',
#   'people'],
#  ['loving', 'much'],
#  ['original',
#   'alexa',
#   'far',
#   '2nd',
#   'generation',
#   'best',
#   'im',
#   'happy',
#   'see',
#   'making',
#   'new',
#   'would',
#   'great',
#   'updates',
#   'little',
#   'think',
#   'would',
#   'help',
#   'lot',
#   'happy',
#   'play',
#   'music',
#   'throughout',
#   'whole',
#   'house',
#   'bass',
#   'thank'],
#  ['pleased',
#   'echo',
#   '2nd',
#   'generation',
#   'nice',
#   'alexa',
#   'available',
#   'music',
#   'weather',
#   'news',
#   'probably',
#   'lot',
#   'havent',
#   'discovered'],
#  ['surprised',
#   'sound',
#   'quality',
#   'echo',
#   'big',
#   'fan',
#   'bass',
#   'might',
#   'though',
#   'potential',
#   'control',
#   'home',
#   'option',
#   'home',
#   'smart',
#   'home',
#   'voice',
#   'recognition',
#   'fun',
#   'purchase',
#   'great',
#   'people',
#   'ask',
#   'play',
#   'song',
#   'movie',
#   'responds',
#   'loved',
#   'would',
#   'great',
#   'gift',
#   'connected',
#   'wifi',
#   'simple',
#   'use',
#   'want',
#   'music',
#   'control',
#   'sure',
#   'amazon',
#   'prime',
#   'spotify',
#   'away',
#   'personal',
#   'even',
#   'echo',
#   'say',
#   'echo',
#   'made',
#   'couple',
#   'times',
#   'ask',
#   'tell',
#   'tells',
#   'since',
#   'amazon',
#   'prime',
#   'comes',
#   'extremely',
#   'handy'],
#  ['easy', 'setup', 'love', 'things'],
#  ['alexa', 'throughout', 'future', 'arrived'],
#  ['already',
#   'alexa',
#   'amazon',
#   'find',
#   'today',
#   'could',
#   'getting',
#   'echo',
#   'also',
#   'best',
#   'ever',
#   'use',
#   'house',
#   'couldnt'],
#  ['arrived', 'expected'],
#  ['weeks',
#   'ago',
#   'everything',
#   'product',
#   'excellent',
#   'dont',
#   'buy',
#   'must',
#   'take',
#   'outside',
#   'put'],
#  [],
#  ['love', 'echo'],
#  ['smaller', 'original', 'looks'],
#  ['works', 'great'],
#  ['husband',
#   'would',
#   'call',
#   '#34',
#   'come',
#   'technology',
#   'would',
#   'try',
#   'echo',
#   'music',
#   'amazed',
#   'great',
#   'sound',
#   'weve',
#   'also',
#   'great',
#   'time',
#   'listening',
#   'favorite',
#   'songs',
#   'buy',
#   'asking',
#   'alexa',
#   'may',
#   'even',
#   'buy',
#   'dad',
#   'think',
#   'enjoy',
#   'listen',
#   'music',
#   'even',
#   'calls',
#   'us'],
#  ['really',
#   'enjoyed',
#   'channels',
#   'plays',
#   'pandora',
#   'thermostat',
#   'turns',
#   'living',
#   'room',
#   'lights',
#   'outside',
#   'lights'],
#  ['prime', 'day', 'absolutely', 'love'],
#  ['glad',
#   'got',
#   'echo',
#   'bluetooth',
#   'speaker',
#   'alexa',
#   'much',
#   'stuff',
#   'smart',
#   'speakers',
#   'love',
#   'timer',
#   'feature',
#   'cooking',
#   'multiple',
#   'things',
#   'pandora',
#   'another',
#   'feature',
#   'use',
#   'daily',
#   'happy',
#   'prime',
#   'day',
#   'purchase',
#   'get',
#   'echo',
#   'hub',
#   'echo',
#   'dots',
#   'future'],
#  ['see', 'love'],
#  ['love'],
#  ['easy', 'setup'],
#  ['buy',
#   'echo',
#   'echo',
#   'seems',
#   'good',
#   'enough',
#   'echo',
#   'except',
#   'sound',
#   'quality',
#   'really',
#   'didnt',
#   'feel',
#   'needed',
#   'however',
#   'glad',
#   'got',
#   'difference',
#   'sound',
#   'really',
#   'far',
#   'echo',
#   'listen',
#   'little',
#   'power'],
#  ['sound', 'quality', 'great', 'learning', 'different', 'things', 'fun'],
#  ['got',
#   'good',
#   'deal',
#   'works',
#   'great',
#   'prime',
#   'setup',
#   'bit',
#   'fault',
#   'internet',
#   'service',
#   'worked',
#   'great',
#   'nice',
#   'sound',
#   'small',
#   'speaker'],
#  ['love'],
#  ['works', 'great', 'perfect', 'office'],
#  ['love', 'house', 'good', 'bose', 'speakers', 'around', 'house'],
#  ['easy'],
#  ['nice', 'product'],
#  ['love',
#   'echo',
#   'totally',
#   'amazed',
#   'speaker',
#   'quality',
#   'didnt',
#   'buy',
#   'two',
#   'since',
#   'got',
#   'prime',
#   'day'],
#  ['responsive', 'great', 'sound', 'quality', 'size'],
#  ['amazing', 'cool', 'use', 'often', 'every', 'day'],
#  ['im',
#   'impressed',
#   'quality',
#   'sound',
#   'echo',
#   'definitely',
#   'bose',
#   'mini',
#   'gave',
#   '4',
#   'stars',
#   'cant',
#   'use',
#   'apple',
#   'music',
#   'account'],
#  ['technology',
#   'small',
#   'device',
#   'price',
#   'good',
#   'sound',
#   'amazing',
#   'must',
#   'feature',
#   'home'],
#  ['mainly',
#   'use',
#   'music',
#   'im',
#   'learning',
#   'time',
#   'really',
#   'nothing',
#   'bad',
#   'say'],
#  ['replaced',
#   '1st',
#   'gen',
#   'smaller',
#   'unit',
#   'wrong',
#   'anything',
#   'volume',
#   'clear',
#   'good',
#   'product'],
#  ['great', 'addition', 'echo', 'plus'],
#  ['best'],
#  ['love', 'feature', 'play', 'music', 'every', 'room', 'multiple', 'echos'],
#  ['love', 'alexa', 'surprised', 'much', 'use'],
#  ['use', 'product', 'love'],
#  ['easy', 'use', 'great', 'great', 'purchase', 'great', 'price'],
#  ['easy', 'set', 'issues'],
#  ['unit',
#   'add',
#   'much',
#   'echo',
#   'plus',
#   'music',
#   'information',
#   'home',
#   'room'],
#  ['extremely',
#   'useful',
#   'simple',
#   'things',
#   'like',
#   'spotify',
#   'audible',
#   'things',
#   'like',
#   'doesnt',
#   'answer',
#   'everything',
#   'ask',
#   'nice',
#   'use'],
#  ['difficult', 'set', 'keeps'],
#  ['getting',
#   'use',
#   'using',
#   'echo',
#   'used',
#   'shopping',
#   'lists',
#   'listening',
#   'music',
#   'timer',
#   'working',
#   'great',
#   'far'],
#  ['cool', 'lots', 'fun', 'used', 'week', 'learning', 'capabilities'],
#  ['love', 'love'],
#  ['love', 'hard', 'time', 'setting', 'apps'],
#  ['use', 'office', 'another', 'music', 'information'],
#  ...]

# %% [markdown]
# ### Let’s create the inputs of model using corpora

# %%
corpora_dict = corpora.Dictionary(clean_list)
corpus = [corpora_dict.doc2bow(line) for line in clean_list]
